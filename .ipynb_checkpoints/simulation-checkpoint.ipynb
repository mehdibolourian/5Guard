# %%
from libraries import *

# %% [markdown]
# # Simulation Setup

# %%
# Parameters for simulation
ITER                    = 2                                 # Iteration count
SIMULATION_INTERVAL     = 40                                # Simulation interval per iteration
TOT_SIMULATION_INTERVAL = max(100, SIMULATION_INTERVAL)     # Total simulation interval
T_START                 = 40                                # Starting time step

SYNTH_BRAIN             = 0                                 # Whether to choose the synthetic topology (0) or BRAIN (1)

gp.setParam("OutputFlag", 0)                                # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-18

# %% [markdown]
# ### 5G Infrastructure Setup

# %%
V_P_S = V_P_R = E_P = E_P_l = L = L_pqi = []
V_P_S, V_P_R, E_P, E_P_l, L, L_pqi = init_setup_synth() if SYNTH_BRAIN == 0 else init_setup_brain()

# %% [markdown]
# ### Slice Request Setup

# %%
# Initialize slice types and probabilities
sr_types = create_sr_resources()
sr_probs = [0.7, 0.15, 0.1, 0.05]  # Probabilities for each type

# Generate SR list
sr_list, sr_type_list = init_setup_sr(ITER, TOT_SIMULATION_INTERVAL, sr_types, sr_probs)

# %% [markdown]
# ### Infrastructure Graph

# %%
plot_synth(V_P_S, V_P_R, E_P) if SYNTH_BRAIN == 0 else plot_brain(V_P_S, V_P_R, E_P)

# %% [markdown]
# ### Data Templates

# %%
data = {}

algs = ["fgr", "opt", "iar", "dtr", "rnr"]
for a in algs:
    data[a] = {
        "profit":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "violat":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 5)), ## 5 for Total (0), Radio (1), Bandwidth (2), MIPS (3), and Delay (4)
        "migrat":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "deploy":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 4)),
        "overhe":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 4)),
        "reseff":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 4)),
        "reject":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 3)),
        "time":    np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "vars":    [[{} for _ in range(T_START+SIMULATION_INTERVAL)] for _ in range(ITER)],
        "feasib":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "timeou":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "R_t":     [[[] for _ in range(T_START+SIMULATION_INTERVAL)] for _ in range(ITER)]
    }

# %% [markdown]
# # Running the Simulation

# %% [markdown]
# ### Saved Data Reuse (from previous runs)

# %%
keys = ["profit", "violat", "migrat", "deploy", "overhe", "reseff", "reject", "time", "vars", "feasib", "timeou", "R_t"]
data_loaded = {}
if T_START > 0:
    for a in algs:
        # Load the lists from the file
        with open(f'saved_data/{a}.pkl', 'rb') as file:
            data_loaded = pickle.load(file)
        
        data[a]["profit"][:, :T_START]    = data_loaded["profit"][:, :T_START]
        data[a]["violat"][:, :T_START, :] = data_loaded["violat"][:, :T_START, :]
        data[a]["migrat"][:, :T_START]    = data_loaded["migrat"][:, :T_START]
        data[a]["deploy"][:, :T_START, :] = data_loaded["deploy"][:, :T_START, :]
        data[a]["overhe"][:, :T_START, :] = data_loaded["overhe"][:, :T_START, :]
        data[a]["reseff"][:, :T_START, :] = data_loaded["reseff"][:, :T_START, :]
        data[a]["reject"][:, :T_START, :] = data_loaded["reject"][:, :T_START, :]
        data[a]["time"][:, :T_START]      = data_loaded["time"][:, :T_START]
        data[a]["feasib"][:, :T_START]    = data_loaded["feasib"][:, :T_START]
        data[a]["timeou"][:, :T_START]    = data_loaded["timeou"][:, :T_START]
        
        # Handle dictionaries and lists separately
        for i in range(ITER):
            for t in range(T_START):
                data[a]["vars"][i][t] = data_loaded["vars"][i][t]
                data[a]["R_t"][i][t]  = data_loaded["R_t"][i][t]

# %% [markdown]
# ### Simulation Run Template

# %%
def run_simulation(alg, ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, func, limit=None):
    """
    Generic simulation function for different algorithms
    
    Parameters:
        alg (str): "fgr", "opt", "iar", "dtr", "rnr"
        ITER (int): Number of iterations
        SIMULATION_INTERVAL (int): Simulation time steps
        sr_list (list): Service request list
        V_P_S, V_P_R, E_P, E_P_l, L, L_pqi: Network elements
        func (function): Optimization function to call (opt_iter or dtr_iter)
        limit (float, optional): Limit parameter for "dtr" algorithm
    """
    file_path = f'saved_data/{alg}.pkl'
    
    for iter in range(ITER):
        if T_START == 0:
            m = gp.Model("e2esliceiso")
            if alg == "fgr":
                m.write(f'saved_model/model_backup_fgr_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_opt_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_iar_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_dtr_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_rnr_{iter}.mps')
            else:
                m.write(f'saved_model/model_backup_{alg}_{iter}.mps')
        
        for t in range(T_START, T_START+SIMULATION_INTERVAL):
            print(f"\niteration: {iter}, Time step: {t}")
            
            prev_profit = data[alg]["profit"][iter][t-1] if t > 0 else 0
            prev_R_t = data[alg]["R_t"][iter][t-1] if t > 0 else []
            
            if alg == "fgr":    # "dtr" requires an additional limit parameter
                result = func(limit, prev_profit, iter, t, sr_list[iter * SIMULATION_INTERVAL + t], prev_R_t, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi)
            elif alg == "dtr":  # "dtr" requires an additional limit parameter + f_fgr = 0
                result = func(limit, prev_profit, iter, t, sr_list[iter * SIMULATION_INTERVAL + t], prev_R_t, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, 0)
            else:
                result = func(prev_profit, iter, t, sr_list[iter * SIMULATION_INTERVAL + t], prev_R_t, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, 0)
            
            keys = ["profit", "violat", "migrat", "deploy", "overhe", "reseff", "reject", "time", "vars", "feasib", "timeou", "R_t"]
            
            if result[9] == 1:  # feasible
                for idx_k, k in enumerate(keys):
                    data[alg][k][iter][t] = result[idx_k]
            else:  # infeasible
                if t > 0:
                    for idx_k, k in enumerate(keys):
                        data[alg][k][iter][t] = data[alg][k][iter][t-1]
                    data[alg]["reject"][iter][t] = result[6]
                    data[alg]["time"][iter][t]   = result[7]
                    data[alg]["feasib"][iter][t] = result[9]
                    data[alg]["timeou"][iter][t] = result[10]
    
    # Save updated data
    with open(file_path, 'wb') as file:
        pickle.dump(data[alg], file)
    
    return data

# %% [markdown]
# ## OPT

# %%
data = run_simulation("opt", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, opt_iter)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 382.813385107355      |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0039010047912597656 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.13636363636364    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (2, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 4805.035607329577     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0070002079010009766 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.13636363636364    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 5942.035607329577   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.00799250602722168 |
# +-------------------------+---------------------+
# | Overhead Cost           | 930.6363636363636   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6424.848992436932    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010038375854492188 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6907.662377544288    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010996341705322266 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7390.475762651642    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.012532949447631836 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0454545454545    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7873.2891477589965   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.026165485382080078 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.1818181818182    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.017648696899414062 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8752.056977818385   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.02001357078552246 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.3636363636364   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 9
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 9889.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.018370628356933594 |
# +-------------------------+----------------------+
# | Overhead Cost           | 1761.8636363636365   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 10
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 10371.87036292574   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.02434062957763672 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1762.0              |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 11
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0136671 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 12
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 11408.87036292574   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06201028823852539 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.5              |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 13
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 11891.683748033094 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.051239013671875  |
# +-------------------------+--------------------+
# | Overhead Cost           | 2692.6363636363635 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 14
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 12374.497133140449   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.035152435302734375 |
# +-------------------------+----------------------+
# | Overhead Cost           | 2692.772727272727    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 15
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 12857.310518247803   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.052510976791381836 |
# +-------------------------+----------------------+
# | Overhead Cost           | 2692.909090909091    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 16
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13340.12390335516   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.07221817970275879 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.0454545454545  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 17
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13822.937288462517  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.05432462692260742 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.181818181818   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 18
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 14305.750673569872  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.05766773223876953 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.318181818182   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 19
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 14788.154954227635            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.07925033569335938           |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | -2.600195024626828e-06        |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -2.3646862246096135e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 2693.863652244314             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 20
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 15271.377443784582  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04830503463745117 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.590909090909   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 21
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 15754.190828891937  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06948184967041016 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.727272727273   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 22
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 16237.004213999291  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08098983764648438 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.8636363636365  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 23
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 16719.817599106646   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.059586524963378906 |
# +-------------------------+----------------------+
# | Overhead Cost           | 2694.0               |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 24
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 17202.630984214     |
# +-------------------------+---------------------+
# | Allocation Time         | 0.07261157035827637 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2694.1363636363635  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 25
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 18331.858256941272   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.060466766357421875 |
# +-------------------------+----------------------+
# | Overhead Cost           | 3532.409090909091    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 26
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 18812.626187503174 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0712130069732666 |
# +-------------------------+--------------------+
# | Overhead Cost           | 3534.590909090909  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 27
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 19294.212299883256            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.0738677978515625            |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3535.9545454545455            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 28
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 19776.61659408152   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08932304382324219 |
# +-------------------------+---------------------+
# | Overhead Cost           | 3536.5              |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 29
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 20258.2027064616    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08251166343688965 |
# +-------------------------+---------------------+
# | Overhead Cost           | 3537.8636363636365  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 30
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 20696.834273384695          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.1295919418334961          |
# +---------------------------+-----------------------------+
# | MIPS Violation Cost       | 48.1818181818155            |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 3538.8181818206285          |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 31
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 21124.420385767222           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.12013030052185059          |
# +---------------------------+------------------------------+
# | MIPS Violation Cost       | 109.54545454545416           |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -3.637978807091713e-13 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 3538.9545454545455           |
# +---------------------------+------------------------------+
#
# iteration: 0, Time step: 32
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 21552.006498147308  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.10350680351257324 |
# +-------------------------+---------------------+
# | MIPS Violation Cost     | 170.90909090908735  |
# +-------------------------+---------------------+
# | Overhead Cost           | 3539.090909090909   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 33
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 21884.18821582661             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.8025238513946533            |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 40.0                          |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | 202.72727272727067            |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3538.272727272727             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 34
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0318494 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 35
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.164135 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 36
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 22312.77433905079             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.522782564163208             |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 40.0                          |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | 264.090897041908              |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.0913936421275138e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3538.409090909091             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 37
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 22721.360440586774  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.41536784172058105 |
# +-------------------------+---------------------+
# | Radio Violation Cost    | 60.0                |
# +-------------------------+---------------------+
# | MIPS Violation Cost     | 325.45454545454413  |
# +-------------------------+---------------------+
# | Overhead Cost           | 3538.5454545454545  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 38
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 23149.946552966852            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.424069881439209             |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 60.0                          |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | 386.8181818181804             |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458563e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3538.681818181818             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 39
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 23558.53266534694  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.7371602058410645 |
# +-------------------------+--------------------+
# | Radio Violation Cost    | 80.0               |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 448.18181818181597 |
# +-------------------------+--------------------+
# | Overhead Cost           | 3538.818181818182  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 0
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 382.813385107355    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01569652557373047 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.13636363636364  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 865.62677021471    |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.27272727272728 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 1348.4401553220648   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015626907348632812 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.4090909090909    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 1744.3946002740977 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.45454545454545 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 2227.207985381453 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 100.5909090909091 |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 2710.0213704888074   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015626192092895508 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.72727272727275   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 3192.8347555961623  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01740717887878418 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.86363636363636  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3675.6481407035176   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.005021095275878906 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.0                |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 4158.461525810872  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0157163143157959 |
# +-------------------------+--------------------+
# | Overhead Cost           | 101.13636363636363 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 9
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 4641.274910918228    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015547752380371094 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.27272727272727   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 10
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 9063.497133140449    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015691518783569336 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.27272727272727   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 11
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 10200.497133140449   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.030757665634155273 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 12
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 10596.497032637937   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.022919178009033203 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 13
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0312662 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 14
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 11079.310417745293  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04390978813171387 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.9090909090909   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 15
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0418308 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 16
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 11562.123802852648   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.031632184982299805 |
# +-------------------------+----------------------+
# | Overhead Cost           | 932.0454545454545    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 17
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12044.937187960002  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03125905990600586 |
# +-------------------------+---------------------+
# | Overhead Cost           | 932.1818181818182   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 18
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12527.750573067357  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04064226150512695 |
# +-------------------------+---------------------+
# | Overhead Cost           | 932.3181818181818   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 19
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13010.563958174711  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03133988380432129 |
# +-------------------------+---------------------+
# | Overhead Cost           | 932.4545454545455   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 20
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13493.377343282065 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0319056510925293 |
# +-------------------------+--------------------+
# | Overhead Cost           | 932.5909090909091  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 21
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 13976.190728389423   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.035851240158081055 |
# +-------------------------+----------------------+
# | Overhead Cost           | 932.7272727272727    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 22
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (1, 0)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 15013.190728389425          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.09864187240600586         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1863.2272727272727          |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 23
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 15496.004102039431           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.11014056205749512          |
# +---------------------------+------------------------------+
# | MIPS Violation Cost       | -2.200165020838085e-06       |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -2.000888343900442e-12 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 1863.3636498011329           |
# +---------------------------+------------------------------+
#
# iteration: 1, Time step: 24
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 15978.817498604134 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.1253376007080078 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1863.5             |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 25
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 16461.63087329572             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.15674209594726562           |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | -2.000150018943714e-06        |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458563e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1863.6363758522698            |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 26
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 16944.444268818843  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.11002898216247559 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1863.7727272727273  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 27
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (1, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 18081.444268818843 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0776069164276123 |
# +-------------------------+--------------------+
# | Overhead Cost           | 2694.272727272727  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 28
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 18564.257653926197 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.1254439353942871 |
# +-------------------------+--------------------+
# | Overhead Cost           | 2694.409090909091  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 29
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0208707 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 30
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 19691.030381198925            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.170365571975708             |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458563e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3535.136363636364             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 31
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 20172.616493579008           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.1569654941558838           |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -3.637978807091713e-13 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 3536.5                       |
# +---------------------------+------------------------------+
#
# iteration: 1, Time step: 32
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 20626.38442414091             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.6815664768218994            |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 10.0                          |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | 20.909090909090267            |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3537.8636363636365            |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 33
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.140883 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 34
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.142286 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 35
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.156739 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 36
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.124808 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 37
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 21057.015991066444 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.7931656837463379 |
# +-------------------------+--------------------+
# | Radio Violation Cost    | 10.0               |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 79.9999999999991   |
# +-------------------------+--------------------+
# | Overhead Cost           | 3538.0             |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 38
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 21475.602103446527           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.6983382701873779           |
# +---------------------------+------------------------------+
# | Radio Violation Cost      | 20.0                         |
# +---------------------------+------------------------------+
# | MIPS Violation Cost       | 141.3636363636361            |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.455191522836685e-12 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 3538.1363636363635           |
# +---------------------------+------------------------------+
#
# iteration: 1, Time step: 39
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 21894.18821582661             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.8256511688232422            |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 30.0                          |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | 202.72727272727258            |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458563e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3538.272727272727             |
# +---------------------------+-------------------------------+

# %% [markdown]
# ## DTR

# %%
LIMIT = 0.6
data = run_simulation("dtr", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, dtr_iter, limit=LIMIT)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 382.813385107355     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.006469011306762695 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4805.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.003908634185791016 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5942.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.005366325378417969 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.6363636363636    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6424.848992436932    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.006652355194091797 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6907.662377544288    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.017465591430664062 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7390.475762651642    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.012955665588378906 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0454545454545    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7873.2891477589965   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.011135578155517578 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.1818181818182    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.019037961959838867 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 8752.056977818385 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 931.3636363636364 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 9
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9889.056977818385             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03428077697753906           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1761.8636363636365            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 10
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10371.87036292574             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.0264434814453125            |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.0                        |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 11
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0150771 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 12
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     | 1       |
# +-----------------------------+---------+
# | Request Isolation Sub-level | 0       |
# +-----------------------------+---------+
# | Allocation Time             | 0.03216 |
# +-----------------------------+---------+
# | Feasible                    | 0       |
# +-----------------------------+---------+
# | Timeout                     | 0       |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 13
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10854.683748033094            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03128790855407715           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.1363636363635            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 14
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11337.497133140449            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.04186415672302246           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.2727272727273            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 15
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11820.310518247803            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.029277563095092773          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.409090909091             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 16
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12303.12390335516             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.02158355712890625           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.5454545454545            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 17
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12785.937288462515            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.030742883682250977          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.6818181818182            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 18
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0464044 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 19
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0313308 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 20
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0312462 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 21
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0410311 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 22
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0283511 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 23
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0422633 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 24
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0346663 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 25
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0455461 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 26
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0304012 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 27
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0371087 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 28
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0462515 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 29
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0207269 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 30
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.040472 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 31
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0477023 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 32
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0228806 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 33
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0385289 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 34
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0157225 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 35
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0404265 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 36
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0305791 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 37
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     | 0       |
# +-----------------------------+---------+
# | Request Isolation Sub-level | 1       |
# +-----------------------------+---------+
# | Allocation Time             | 0.03947 |
# +-----------------------------+---------+
# | Feasible                    | 0       |
# +-----------------------------+---------+
# | Timeout                     | 0       |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 38
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0444782 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 39
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0331633 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 0
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 382.813385107355   |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.13636363636364 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 865.62677021471    |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.27272727272728 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 1348.4401553220648 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.4090909090909  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 1744.3946002740977  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01813054084777832 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.45454545454545  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 2227.207985381453 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 100.5909090909091 |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 2710.0213704888074   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015738248825073242 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.72727272727275   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3192.8347555961623   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.012118101119995117 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.86363636363636   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3675.6481407035176   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.005467891693115234 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.0                |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 4158.461525810872    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.017439603805541992 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.13636363636363   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 9
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 4641.274910918228    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.018825054168701172 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.27272727272727   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 10
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (2, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9063.49713314045              |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.02778482437133789           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 101.27272727272727            |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 11
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10200.49713314045             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.017989158630371094          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.7727272727273             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 12
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10596.497032637939            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.026090383529663086          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.7727272727273             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 13
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0269117 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 14
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11079.310417745295            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03685903549194336           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.9090909090909             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 15
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0336883 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 16
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11562.12380285265             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.02881026268005371           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.0454545454545             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 17
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12044.937187960004            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.0389552116394043            |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.1818181818182             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 18
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12527.750573067358            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.036483049392700195          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.3181818181818             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 19
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 13010.563958174713            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.02992868423461914           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.4545454545455             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 20
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 13493.377343282067            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03541398048400879           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.5909090909091             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 21
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 13976.190728389425            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.04631805419921875           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.7272727272727             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 22
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0287395 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 23
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 14459.00411349678             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03949117660522461           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.8636363636364             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 24
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 14941.817498604134            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03522944450378418           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.0                         |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 25
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 15424.630883711488            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.04019904136657715           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.1363636363636             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 26
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 15907.444268818843            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.04453921318054199           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.2727272727273             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 27
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0496433 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 28
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 16390.257653926197            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.05986642837524414           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.4090909090909             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 29
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0200005 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 30
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0531077 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 31
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 16873.07103903355             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.04792308807373047           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.5454545454545             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 32
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 17355.884424140906            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03975725173950195           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.6818181818182             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 33
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0505455 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 34
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0547948 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 35
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0563807 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 36
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0468407 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 37
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 17838.697809248264            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.04473543167114258           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.8181818181818             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 38
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 18321.51119435562             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.04695940017700195           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 933.9545454545455             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 39
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 18804.324579462973            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.07291316986083984           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 934.0909090909091             |
# +---------------------------+-------------------------------+

# %% [markdown]
# ## RNR

# %%
data = run_simulation("rnr", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, rnr_iter)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 382.813385107355     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.006207942962646484 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4805.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.012406110763549805 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5942.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.006365776062011719 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.6363636363636    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6424.848992436932    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.019800424575805664 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 6907.662377544288 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 930.9090909090909 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 7390.475762651642  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0128021240234375 |
# +-------------------------+--------------------+
# | Overhead Cost           | 931.0454545454545  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7873.2891477589965   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.006727695465087891 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.1818181818182    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.009239912033081055 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8752.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.012586116790771484 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.3636363636364    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 9
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9889.056977818385             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.020328760147094727          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1761.8636363636365            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 10
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10371.87036292574             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.021097660064697266          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.0                        |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 11
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 2          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00993443 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 0, Time step: 12
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.042753 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 13
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10854.683748033094            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.020307302474975586          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.1363636363635            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 14
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11337.497133140449            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03440284729003906           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.2727272727273            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 15
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11820.310518247803            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.02014923095703125           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.409090909091             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 16
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12303.12390335516             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.024407625198364258          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.5454545454545            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 17
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12785.937288462515            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.024379491806030273          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.6818181818182            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 18
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0419812 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 19
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.049629 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 20
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0363121 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 21
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0743747 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 22
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0340009 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 23
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0349941 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 24
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0474789 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 25
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 14019.583757836812            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.025213956832885742          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 2496.535348807523             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 26
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0369956 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 27
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 14401.989273089852            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03960251808166504           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 2597.079582298202             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 28
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0345521 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 29
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0418925 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 30
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 14984.377885693666          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.034093618392944336        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 2497.6407184381055          |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 31
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0300639 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 32
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 15366.750113311065           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.03502702713012695          |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -2.728484105318785e-12 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 2598.2182395644286           |
# +---------------------------+------------------------------+
#
# iteration: 0, Time step: 33
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 0)                       |
# +---------------------------+------------------------------+
# | Profit                    | 15862.204361966507           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.03643631935119629          |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -4.500400052620535e-13 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 2498.7638904064684           |
# +---------------------------+------------------------------+
#
# iteration: 0, Time step: 34
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0200872 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 35
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.054028 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 36
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0451088 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 37
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0391653 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 38
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 16345.056575452305           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.02866053581237793          |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -2.910383045673371e-12 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 2498.8614256643928           |
# +---------------------------+------------------------------+
#
# iteration: 0, Time step: 39
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 16826.893559421198            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.030128955841064453          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 2499.9741904392176            |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 0
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 382.813385107355     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010075569152832031 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 865.62677021471    |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.27272727272728 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 1348.4401553220648 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.4090909090909  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 1744.3946002740977   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.009506464004516602 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.45454545454545   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 2227.207985381453 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 100.5909090909091 |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 2710.0213704888074  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.00854802131652832 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.72727272727275  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 3192.8347555961623  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01992630958557129 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.86363636363636  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3675.6481407035176   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.008046627044677734 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.0                |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 4158.461525810872    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010959386825561523 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.13636363636363   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 9
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 4641.274910918228    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.014670372009277344 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.27272727272727   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 10
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (2, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9063.49713314045              |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.020003318786621094          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 101.27272727272727            |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 11
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10200.49713314045             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03237605094909668           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.7727272727273             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 12
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10596.497032637939            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.01877593994140625           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.7727272727273             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 13
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0310376 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 14
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11079.310417745295            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.01992511749267578           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.9090909090909             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 15
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11753.088095020561            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.02374577522277832           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.9090909090909             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 16
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0283668 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 17
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0299358 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 18
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0339727 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 19
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0412388 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 20
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12235.901480127915            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.016396045684814453          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 932.0454545454545             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 21
# Infeasible rounding with infeasible constraints: [6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0346575 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 22
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0313294 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 23
# Infeasible rounding with infeasible constraints: [6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0372639 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 24
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0414402 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 25
# Infeasible rounding with infeasible constraints: [6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0499876 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 26
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0401886 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 27
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0307975 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 28
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0448899 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 29
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0155535 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 30
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0317736 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 31
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0383043 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 32
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0242534 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 33
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 13372.901480127886            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.031177043914794922          |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 2.9103830456733704e-11        |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.5454545454536            |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 34
# Infeasible rounding with infeasible constraints: [3 4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0581336 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 35
# Infeasible rounding with infeasible constraints: [3 4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0329254 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 36
# Infeasible rounding with infeasible constraints: [3 4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0318024 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 37
# Infeasible rounding with infeasible constraints: [3 4 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0338361 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 38
# Infeasible rounding with infeasible constraints: [3 4 6]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.031251 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 39
# Infeasible rounding with infeasible constraints: [3 4 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0464802 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+

# %% [markdown]
# ## IAR

# %%
data = run_simulation("iar", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, iar_iter)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 381.5861123800822  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 101.36363636363637 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4803.808334603906    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.013404130935668945 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.36363636363637   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (1, 0)            |
# +-------------------------+-------------------+
# | Profit                  | 5940.808334603906 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 931.8636363636364 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 6422.394446969032     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0010716915130615234 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 933.2272727272727     |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 6903.98055934906      |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0018994808197021484 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 934.590909090909      |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 7385.566671729088 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 935.9545454545455 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 7867.152784109116 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 937.3181818181818 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 0)            |
# +-------------------------+-------------------+
# | Profit                  | 8262.698138147593 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 937.7727272727273 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 8744.28425051272  |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 939.1363636363636 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 9
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 9881.28425051272    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01565098762512207 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1769.6363636363635  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 10
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 10362.870362892747    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0030727386474609375 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1771.0                |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 11
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000002215A887790> of SR <data.sr object at 0x000002215A887ED0>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 12
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       1 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 13
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 10844.456475272775 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1772.3636363636365 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 14
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 11326.042587637901 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1773.7272727272727 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 15
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 11807.628700017929   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015601873397827148 |
# +-------------------------+----------------------+
# | Overhead Cost           | 1775.090909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 16
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 12289.214812397957 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1776.4545454545455 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 17
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 12709.437288418412 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 68.18181818181782  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1777.8181818181818 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 18
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 13124.750673517585   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015627622604370117 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 141.8181818181818    |
# +-------------------------+----------------------+
# | Overhead Cost           | 1779.1818181818182   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 19
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13540.064058631659 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 215.4545454545451  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1780.5454545454545 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 20
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 13955.377443745732    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0012319087982177734 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 289.0909090909091     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1781.909090909091     |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 21
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 14370.690828859806   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.002279996871948242 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 362.7272727272724    |
# +-------------------------+----------------------+
# | Overhead Cost           | 1783.2727272727273   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 22
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 14786.004213958979 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.00311279296875   |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 436.3636363636357  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1784.6363636363635 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 23
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 15201.317599073052 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 509.9999999999997  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1786.0             |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 24
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 15616.630984187126    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0005967617034912109 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 583.6363636363637     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1787.3636363636365    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 25
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 1          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00259233 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 0, Time step: 26
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 16031.944369286299    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0010673999786376953 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 657.272727272727      |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1788.7272727272727    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 27
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 16447.257754400373    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0010218620300292969 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 730.9090909090903     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1790.090909090909     |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 28
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 16862.571139514446    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0019211769104003906 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 804.5454545454543     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1791.4545454545455    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 29
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 17277.88452462852  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 878.1818181818176  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1792.8181818181818 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 30
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 17693.197909742594  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01554250717163086 |
# +-------------------------+---------------------+
# | MIPS Violation Cost     | 951.8181818181816   |
# +-------------------------+---------------------+
# | Overhead Cost           | 1794.1818181818182  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 31
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 18108.511294856668 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 1025.454545454545  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1795.5454545454545 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 32
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 18523.82467997074    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.016353368759155273 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 1099.090909090909    |
# +-------------------------+----------------------+
# | Overhead Cost           | 1796.909090909091    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 33
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 0)            |
# +-------------------------+-------------------+
# | Profit                  | 18883.82457946241 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | MIPS Violation Cost     | 1139.090909090909 |
# +-------------------------+-------------------+
# | Overhead Cost           | 1796.909090909091 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 34
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000002215A887790> of SR <data.sr object at 0x000002215A887ED0>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 35
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0157125 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 36
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 19299.137964576483 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 1212.7272727272723 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1798.2727272727273 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 37
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 19714.451349675655 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 1286.3636363636356 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1799.6363636363635 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 38
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 20129.76473478973  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 1359.9999999999995 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1801.0             |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 39
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 20545.078119903803 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 1433.6363636363635 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1802.3636363636365 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 0
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 381.5861123800822  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 101.36363636363637 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 863.1722247601645  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 102.72727272727272 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 1344.758337140247  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 104.09090909090908 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 1740.3036911831891 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 104.54545454545453 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 2221.889803563271    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.002012014389038086 |
# +-------------------------+----------------------+
# | Overhead Cost           | 105.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 2703.475915943353    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.001489400863647461 |
# +-------------------------+----------------------+
# | Overhead Cost           | 107.27272727272727   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3185.062028323435    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.002008199691772461 |
# +-------------------------+----------------------+
# | Overhead Cost           | 108.63636363636363   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 3666.648140703517 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 110.0             |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 4148.2342530835995 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 111.36363636363637 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 9
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 4629.820365463681     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0015902519226074219 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 112.72727272727272    |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 10
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (2, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 9052.042587682605     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0010895729064941406 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 112.72727272727272    |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 11
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 10189.042587682605   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.009005069732666016 |
# +-------------------------+----------------------+
# | Overhead Cost           | 943.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 12
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 10585.042487174273   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010755777359008789 |
# +-------------------------+----------------------+
# | Overhead Cost           | 943.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 13
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0118759 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 14
# +-------------------------+------------------+
# | Category                | Value            |
# +=========================+==================+
# | Algorithm               | RNR              |
# +-------------------------+------------------+
# | Request Isolation Level | (0, 1)           |
# +-------------------------+------------------+
# | Profit                  | 11066.6285995543 |
# +-------------------------+------------------+
# | Allocation Time         | 0.0              |
# +-------------------------+------------------+
# | Overhead Cost           | 944.590909090909 |
# +-------------------------+------------------+
#
# iteration: 1, Time step: 15
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       0 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 1, Time step: 16
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 11548.214711934328    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0015981197357177734 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 945.9545454545455     |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 17
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 12029.800824314356   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.003048419952392578 |
# +-------------------------+----------------------+
# | Overhead Cost           | 947.3181818181818    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 18
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12511.386936679482  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.00944066047668457 |
# +-------------------------+---------------------+
# | Overhead Cost           | 948.6818181818182   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 19
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 12992.97304905951    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.002613067626953125 |
# +-------------------------+----------------------+
# | Overhead Cost           | 950.0454545454545    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 20
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 13474.559161439538    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0024759769439697266 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 951.4090909090909     |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 21
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 13956.145273819566   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.003924369812011719 |
# +-------------------------+----------------------+
# | Overhead Cost           | 952.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 22
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (1, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 15093.145273819566 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1783.2727272727273 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 23
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 15574.731386184692 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1784.6363636363635 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 24
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 16029.31749856472    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.006513118743896484 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 29.999999999999883   |
# +-------------------------+----------------------+
# | Overhead Cost           | 1786.0               |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 25
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 16444.630883678794 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 103.63636363636394 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1787.3636363636365 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 26
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 16859.944268777966 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 177.2727272727272  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1788.7272727272727 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 27
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 1          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00213146 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 1, Time step: 28
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 17275.25765389204    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.004223823547363281 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 250.90909090909048   |
# +-------------------------+----------------------+
# | Overhead Cost           | 1790.090909090909    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 29
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000002215BA88FD0> of SR <data.sr object at 0x000002215BA88C90>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 1, Time step: 30
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 1          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00201631 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 1, Time step: 31
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 17690.571039006114    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0022933483123779297 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 324.5454545454545     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1791.4545454545455    |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 32
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 18105.884424120188   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.003378629684448242 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 398.1818181818178    |
# +-------------------------+----------------------+
# | Overhead Cost           | 1792.8181818181818   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 33
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 1          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00501108 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 1, Time step: 34
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 1          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00306201 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 1, Time step: 35
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0101049 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 36
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       1 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 1, Time step: 37
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 18521.19780921936  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 471.8181818181818  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1794.1818181818182 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 38
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 18936.511194333434 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 545.454545454545   |
# +-------------------------+--------------------+
# | Overhead Cost           | 1795.5454545454545 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 39
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 19351.824579447508   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.017511606216430664 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 619.0909090909091    |
# +-------------------------+----------------------+
# | Overhead Cost           | 1796.909090909091    |
# +-------------------------+----------------------+

# %% [markdown]
# ## 5Guard

# %%
LIMIT = 0.2

data = run_simulation("fgr", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, fgr_iter, limit=LIMIT)

# Load the lists from the file
with open('saved_data/fgr.pkl', 'rb') as file:
    data_loaded = pickle.load(file)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 382.813385107355      |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0056073665618896484 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.13636363636364    |
# +-------------------------+-----------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 381.5861123800822    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010013103485107422 |
# +-------------------------+----------------------+
# | Overhead Cost           | 101.36363636363637   |
# +-------------------------+----------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 382.813385107355    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.00603938102722168 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.13636363636364  |
# +-------------------------+---------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 382.813385107355     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.009511709213256836 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4805.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.029100894927978516 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (2, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 4803.808334603906   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04144620895385742 |
# +-------------------------+---------------------+
# | Overhead Cost           | 101.36363636363637  |
# +-------------------------+---------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4805.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.021521806716918945 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (2, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 4805.035607329577     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0011761188507080078 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.13636363636364    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5940.808334603906    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.020383834838867188 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.8636363636364    |
# +-------------------------+----------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5942.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.030508756637573242 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.6363636363636    |
# +-------------------------+----------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5942.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.027357816696166992 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.6363636363636    |
# +-------------------------+----------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5942.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.013873577117919922 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.6363636363636    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6422.394446969032    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.025816679000854492 |
# +-------------------------+----------------------+
# | Overhead Cost           | 933.2272727272727    |
# +-------------------------+----------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 6424.848992436932   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04913926124572754 |
# +-------------------------+---------------------+
# | Overhead Cost           | 930.7727272727273   |
# +-------------------------+---------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6424.848992436932    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.006505012512207031 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.7727272727273    |
# +-------------------------+----------------------+
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 6424.848992436932  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0165102481842041 |
# +-------------------------+--------------------+
# | Overhead Cost           | 930.7727272727273  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 6907.662377544288  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0601506233215332 |
# +-------------------------+--------------------+
# | Overhead Cost           | 930.9090909090909  |
# +-------------------------+--------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6903.98055934906     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.060158491134643555 |
# +-------------------------+----------------------+
# | Overhead Cost           | 934.590909090909     |
# +-------------------------+----------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 6907.662377544288   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03353095054626465 |
# +-------------------------+---------------------+
# | Overhead Cost           | 930.9090909090909   |
# +-------------------------+---------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6907.662377544288    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.039404869079589844 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7390.475762651642    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.059946537017822266 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0454545454545    |
# +-------------------------+----------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7385.566671729088    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.040619850158691406 |
# +-------------------------+----------------------+
# | Overhead Cost           | 935.9545454545455    |
# +-------------------------+----------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7390.475762651642    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.028722047805786133 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0454545454545    |
# +-------------------------+----------------------+
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 7390.475762651642  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0336613655090332 |
# +-------------------------+--------------------+
# | Overhead Cost           | 931.0454545454545  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 7867.152784109116   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01998138427734375 |
# +-------------------------+---------------------+
# | Overhead Cost           | 937.3181818181818   |
# +-------------------------+---------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 7873.2891477589965  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06372761726379395 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.1818181818182   |
# +-------------------------+---------------------+
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 7873.2891477589965 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0593264102935791 |
# +-------------------------+--------------------+
# | Overhead Cost           | 931.1818181818182  |
# +-------------------------+--------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7873.2891477589965   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.022439002990722656 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.1818181818182    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 8262.698138147593   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.05426454544067383 |
# +-------------------------+---------------------+
# | Overhead Cost           | 937.7727272727273   |
# +-------------------------+---------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 8269.243592711031   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08686232566833496 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.2272727272727   |
# +-------------------------+---------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 8269.243592711031   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08649039268493652 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.2272727272727   |
# +-------------------------+---------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 8269.243592711031   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06264281272888184 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.2272727272727   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8744.28425051272    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08334684371948242 |
# +-------------------------+---------------------+
# | Overhead Cost           | 939.1363636363636   |
# +-------------------------+---------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8752.056977818385   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.09734654426574707 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.3636363636364   |
# +-------------------------+---------------------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8752.056977818385   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06284928321838379 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.3636363636364   |
# +-------------------------+---------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8752.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.058193206787109375 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.3636363636364    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 9
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 9889.056977818385   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.05117607116699219 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1761.8636363636365  |
# +-------------------------+---------------------+
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 9881.28425051272     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.061394453048706055 |
# +-------------------------+----------------------+
# | Overhead Cost           | 1769.6363636363635   |
# +-------------------------+----------------------+
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9889.056977818385             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.06300663948059082           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1761.8636363636365            |
# +---------------------------+-------------------------------+
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9889.056977818385             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03976130485534668           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1761.8636363636365            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 10
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 10362.870362892747  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03200507164001465 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1771.0              |
# +-------------------------+---------------------+
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 10371.87036292574  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0848245620727539 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1762.0             |
# +-------------------------+--------------------+
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10371.87036292574             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.07717609405517578           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.0                        |
# +---------------------------+-------------------------------+
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10371.87036292574             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.015770912170410156          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.0                        |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 11
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000002215A887790> of SR <data.sr object at 0x000002215A887ED0>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 2        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.111029 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0813286 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0507686 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 12
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 11408.87036292574   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.10827207565307617 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.5              |
# +-------------------------+---------------------+
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.115528 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0939529 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (1, 0)                       |
# +---------------------------+------------------------------+
# | Profit                    | 11507.282912332854           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.08271646499633789          |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -3.637978807091713e-13 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 2594.0874505928855           |
# +---------------------------+------------------------------+
#
# iteration: 0, Time step: 13
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.109593 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 11891.683748033094  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.12954330444335938 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.6363636363635  |
# +-------------------------+---------------------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0734575 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0905449 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 14
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0911224 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12374.497133140449  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08698296546936035 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.772727272727   |
# +-------------------------+---------------------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0560889 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0958042 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 15
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12857.310518247803  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.10993599891662598 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.909090909091   |
# +-------------------------+---------------------+
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.105625 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0853868 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.107812 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 16
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0818057 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13340.12390335516  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.1319580078125    |
# +-------------------------+--------------------+
# | Overhead Cost           | 2693.0454545454545 |
# +-------------------------+--------------------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0470665 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0667002 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 17
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0806766 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0845981 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.124596 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13822.937288462517 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.1952815055847168 |
# +-------------------------+--------------------+
# | Overhead Cost           | 2693.181818181818  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 18
# +-----------------------------+----------+
# | Category                    |    Value |
# ...
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.213933 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# Infeasible rounding with infeasible constraints: [2 3 4 6 8]
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     | 1       |
# +-----------------------------+---------+
# | Request Isolation Sub-level | 0       |
# +-----------------------------+---------+
# | Allocation Time             | 0.12363 |
# +-----------------------------+---------+
# | Feasible                    | 0       |
# +-----------------------------+---------+
# | Timeout                     | 0       |
# +-----------------------------+---------+
# Infeasible rounding with infeasible constraints: [2 3 6 8]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.143047 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 35
# infeasible: Checked all possible NR-BSs. No remaining NR-BS for mapping RU <data.ru object at 0x000002215BA896D0> of SR <data.sr object at 0x000002215BA894D0>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       1 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
# Infeasible rounding with infeasible constraints: [2 3 4 6 8]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.125432 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.288471 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# Infeasible rounding with infeasible constraints: [2 3 4 6 8]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.176051 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 36
# infeasible: Checked all possible NR-BSs. No remaining NR-BS for mapping RU <data.ru object at 0x000002215BA896D0> of SR <data.sr object at 0x000002215BA894D0>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       1 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     | 1       |
# +-----------------------------+---------+
# | Request Isolation Sub-level | 0       |
# +-----------------------------+---------+
# | Allocation Time             | 0.22888 |
# +-----------------------------+---------+
# | Feasible                    | 0       |
# +-----------------------------+---------+
# | Timeout                     | 0       |
# +-----------------------------+---------+
# Infeasible rounding with infeasible constraints: [2 3 4 6 8]
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     | 1       |
# +-----------------------------+---------+
# | Request Isolation Sub-level | 0       |
# +-----------------------------+---------+
# | Allocation Time             | 0.15043 |
# +-----------------------------+---------+
# | Feasible                    | 0       |
# +-----------------------------+---------+
# | Timeout                     | 0       |
# +-----------------------------+---------+
# Infeasible rounding with infeasible constraints: [2 3 6 8]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.122829 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 37
# infeasible: Checked all possible NR-BSs. No remaining NR-BS for mapping RU <data.ru object at 0x000002215BA91E10> of SR <data.sr object at 0x000002215BA91C10>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       0 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       1 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
# Infeasible rounding with infeasible constraints: [3 4 6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0812523 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
# Infeasible rounding with infeasible constraints: [3 4 6]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.145297 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | RNR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 21057.015991066444 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.8523197174072266 |
# +-------------------------+--------------------+
# | Radio Violation Cost    | 10.0               |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 79.9999999999991   |
# +-------------------------+--------------------+
# | Overhead Cost           | 3538.0             |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 38
# infeasible: Checked all possible NR-BSs. No remaining NR-BS for mapping RU <data.ru object at 0x000002215BA91E10> of SR <data.sr object at 0x000002215BA91C10>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       0 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       1 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
# Infeasible rounding with infeasible constraints: [3 4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.127676 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# Infeasible rounding with infeasible constraints: [3]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.171065 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | RNR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 21475.602103446527           |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.7122857570648193           |
# +---------------------------+------------------------------+
# | Radio Violation Cost      | 20.0                         |
# +---------------------------+------------------------------+
# | MIPS Violation Cost       | 141.3636363636361            |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.455191522836685e-12 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 3538.1363636363635           |
# +---------------------------+------------------------------+
#
# iteration: 1, Time step: 39
# infeasible: Checked all possible NR-BSs. No remaining NR-BS for mapping RU <data.ru object at 0x000002215BA91E10> of SR <data.sr object at 0x000002215BA91C10>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       0 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       1 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
# Infeasible rounding with infeasible constraints: [3 4 6]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.137867 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# Infeasible rounding with infeasible constraints: [3 6]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.169566 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | RNR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 21894.18821582661             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.7918984889984131            |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 30.0                          |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | 202.72727272727258            |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458563e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3538.272727272727             |
# +---------------------------+-------------------------------+

# %% [markdown]
# # Results

# %% [markdown]
# ### Find the data average and error bars

# %%
data_avg = copy.deepcopy(data)

kpis = ["profit", "violat", "migrat", "deploy", "overhe", "reseff", "reject", "time"]

for a in algs:
    for k in kpis:
        data_avg[a][k]  = np.sum(data[a][k], axis=0) / ITER

# %% [markdown]
# ### Plot Settings

# %%
plt.rcParams['font.family']  = 'DeJavu Serif'
plt.rcParams['font.serif']   = ['Times New Roman']
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype']  = 42

# Constants
bar_width       = 0.13
markevery       = 10
linewidth       = 5
marker_size     = 17
markeredgewidth = 4
step            = 5  # Error bars frequency

tick_label_size, legend_font_size, xlabel_font_size, ylabel_font_size = 25, 18, 23, 23

kpi1  = ["reject"]
kpis2 = ["profit", "migrat"]
kpis3 = ["violat", "deploy", "overhe", "reseff"]
kpi4  = ["time"]

xpoints = range(0, T_START+SIMULATION_INTERVAL)
ypoints = data_avg.copy()
yerrors_low  = {alg: {k: np.min(data[a][k], axis=0) for k in kpis2+kpis3+kpi4} for alg in algs}  # Lower bound errors
yerrors_high = {alg: {k: np.max(data[a][k], axis=0) for k in kpis2+kpis3+kpi4} for alg in algs}  # Upper bound errors

plot_titles = [
    ('Isolation Level', 'Slice Admission (%)'),
    ('$\it{t}$', 'Profit'),
    ('$\it{t}$', 'Cumulative Migration'),
    ('$\it{t}$', 'Aggregate Violation Cost'),   
    ('$\it{t}$', 'Aggregate Deployment Cost'),
    ('$\it{t}$', 'Aggregate Overhead Cost'),
    ('$\it{t}$', 'Resource Efficiency (%)'),
]

colors  = ["#646464", "#EE0000", "#6E8EE6", "#21CD7D", "#00FF00"]
markers = ['o', 'v', 'h', '^', 'D']

patterns = ['/', '\\', 'O', '-', '...']

# %% [markdown]
# ## Slice Admission

# %%
fig, ax = plt.subplots(figsize=(7, 6))
positions = [np.arange(3) + i * bar_width for i in range(len(algs))]

for i, alg in enumerate(algs):
    NUM_L0_SR = sr_type_list.count(0) + sr_type_list.count(2)
    NUM_L1_SR = sr_type_list.count(1)
    NUM_L2_SR = sr_type_list.count(3)
    denominator = np.clip([NUM_L0_SR, NUM_L1_SR, NUM_L2_SR], 1e-9, None)
    
    values = (1 - np.sum(np.array(ypoints[alg]["reject"]), axis=0) / denominator) * 100
    values = [min(a, b) for a, b in zip(values, [100, 100, 100])]

    #print(data[alg]["reject"])
    # Extracting error values
    err_low  = values - list([np.min((1 - np.sum(np.array(data[alg]["reject"]), axis=1) / denominator), axis=0) * 100])[0]
    err_high = list([np.max((1 - np.sum(np.array(data[alg]["reject"]), axis=1) / denominator), axis=0) * 100])[0] - values
    
    # Adding bars with error bars
    ax.bar(positions[i], values, width=bar_width, color=colors[i], edgecolor='black', hatch=patterns[i],
           yerr=[err_low, err_high], capsize=5, error_kw={'elinewidth': 3, 'capthick': 1.5, 'capsize': 4})

ax.set_xticks(positions[2])
ax.set_xticklabels(['0', '1', '2'])
ax.set_ylim(top=119)

ax.tick_params(axis='both', labelsize=tick_label_size)
ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR'], fontsize=legend_font_size-3, loc='upper center', ncol=3)

ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.yaxis.get_major_formatter().set_scientific(True)
ax.yaxis.get_major_formatter().set_powerlimits((-1, 1))
ax.yaxis.offsetText.set_fontsize(20)  # Adjust font size

ax.set_xlabel(plot_titles[0][0], fontsize=xlabel_font_size)
ax.set_ylabel(plot_titles[0][1], fontsize=ylabel_font_size)
fig.tight_layout(pad=0.5)
plt.savefig(f"plots/result_{0}.svg", format="svg")

# %% [markdown]
# ## Profit and Cumulative Migration

# %%
for idx_k, k in enumerate(kpis2):
    fig, ax = plt.subplots(figsize=(7, 6))

    for i, alg in enumerate(algs):
        ax.errorbar(xpoints, ypoints[alg][k],  
                    yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerrors_low[alg][k], np.nan),  
                          np.where(np.arange(len(xpoints)) % step == 0, yerrors_high[alg][k], np.nan)),  
                    marker=markers[i], markevery=markevery, markersize=marker_size,
                    color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
                    markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle='-')
    ax.grid()
    
    plt.xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))

    ax.tick_params(axis='both', labelsize=tick_label_size)
    ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR'], fontsize=legend_font_size)

    ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    ax.yaxis.get_major_formatter().set_scientific(True)
    ax.yaxis.get_major_formatter().set_powerlimits((-1, 1))
    ax.yaxis.offsetText.set_fontsize(20)  # Adjust font size
    
    ax.set_xlabel(plot_titles[idx_k+1][0], fontsize=xlabel_font_size)
    ax.set_ylabel(plot_titles[idx_k+1][1], fontsize=ylabel_font_size)
    fig.tight_layout(pad=0.5)
    plt.savefig(f"plots/result_{idx_k+1}.svg", format="svg")

# %% [markdown]
# ## Allocation Time

# %%
xpoints = range(0, T_START+SIMULATION_INTERVAL)
kpi     = "time"
colors  = ["#646464", "#EE0000", "#6E8EE6", "#21CD7D", "#00FF00"]
markers = ['o', 'v', 'h', '^', 'D']
limits  = np.array([4, 5, 1, 0.5])*0.01

# Plot setup
fig, ax = plt.subplots(figsize=(10, 4.75))
for i, alg in enumerate(algs):
    # ax.errorbar(xpoints, ypoints[alg][kpi], 
    #                 yerr=(yerrors_low[alg][kpi], yerrors_high[alg][kpi]),  # Asymmetric error bars
    #                 marker=markers[i], markevery=10, markersize=marker_size,
    #                 color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
    #                 markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle='-')
    ax.errorbar(xpoints, ypoints[alg][kpi],  
                    yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerrors_low[alg][kpi], np.nan),  
                          np.where(np.arange(len(xpoints)) % step == 0, yerrors_high[alg][kpi], np.nan)),  
                    marker=markers[i], markevery=markevery, markersize=marker_size,
                    color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
                    markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle='-')
    

# Formatting
ax.grid()
ax.tick_params(axis='both', labelsize=25)
ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR'], fontsize=18)
ax.set_xlabel('$\it{t}$', fontsize=25)
ax.set_ylabel('Allocation Time (sec.)', fontsize=25)
ax.set_xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))

# Add dashed limit lines
for limit in limits:
    ax.axhline(y=limit, color='#000000', linestyle='--', linewidth=2)
    
fig.tight_layout(pad=0.5)

# Save & show
plt.savefig("plots/result_8.svg", format="svg")
plt.show()

# %% [markdown]
# ## Violation, Deployment, and Overhead Costs and Resource Efficiency

# %%
for idx_k, k in enumerate(kpis3):
    fig, ax = plt.subplots(figsize=(7, 6))
    
    for i, alg in enumerate(algs):
        ax.errorbar(xpoints, ypoints[alg][k][:,0],  
                    yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerrors_low[alg][k][:,0], np.nan),  
                          np.where(np.arange(len(xpoints)) % step == 0, yerrors_high[alg][k][:,0], np.nan)),  
                    marker=markers[i], markevery=markevery, markersize=marker_size,
                    color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
                    markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle='-')
    ax.grid()
    
    plt.xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))

    ax.tick_params(axis='both', labelsize=tick_label_size)
    ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR'], fontsize=legend_font_size)

    if k != "reseff": ## Percentage data
        ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        ax.yaxis.get_major_formatter().set_scientific(True)
        ax.yaxis.get_major_formatter().set_powerlimits((-1, 1))
        ax.yaxis.offsetText.set_fontsize(20)  # Adjust font size
    
    ax.set_xlabel(plot_titles[idx_k+3][0], fontsize=xlabel_font_size)
    ax.set_ylabel(plot_titles[idx_k+3][1], fontsize=ylabel_font_size)
    fig.tight_layout(pad=0.5)
    plt.savefig(f"plots/result_{idx_k+3}.svg", format="svg")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 5
#       2 fig, ax = plt.subplots(figsize=(7, 6))
#       4 for i, alg in enumerate(algs):
# ----> 5     ax.errorbar(xpoints, ypoints[alg][k][:,0],
#       6                 yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerrors_low[alg][k][:,0], np.nan),
#       7                       np.where(np.arange(len(xpoints)) % step == 0, yerrors_high[alg][k][:,0], np.nan)),
#       8                 marker=markers[i], markevery=markevery, markersize=marker_size,
#       9                 color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
#      10                 markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle='-')
#      11 ax.grid()
#      13 plt.xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:3674, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3671 res = np.zeros(err.shape, dtype=bool)  # Default in case of nan
#    3672 if np.any(np.less(err, -err, out=res, where=(err == err))):
#    3673     # like err<0, but also works for timedelta and nan.
# -> 3674     raise ValueError(
#    3675         f"'{dep_axis}err' must not contain negative values")
#    3676 # This is like
#    3677 #     elow, ehigh = np.broadcast_to(...)
#    3678 #     return dep - elow * ~lolims, dep + ehigh * ~uplims
#    3679 # except that broadcast_to would strip units.
#    3680 low, high = dep + np.vstack([-(1 - lolims), 1 - uplims]) * err
#
# ValueError: 'yerr' must not contain negative values
