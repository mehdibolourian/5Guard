# %%
from libraries import *

# %% [markdown]
# ## Simulation Setup

# %%
V_P_S = V_P_R = E_P = E_P_l = L = L_pqi = []
SIMULATION_INTERVAL = ITER = 0

SYNTH_BRAIN = 0
V_P_S, V_P_R, E_P, E_P_l, L, L_pqi = init_setup_synth() if SYNTH_BRAIN == 0 else init_setup_brain()

# %%
vservers = []
vservers.append(vserver(4000*MIPS_SCALE, 5, [0,1,2,3,4])) ## Mobility management entity (MME)
rus      = [ru(100)]
vpaths   = []
vpaths.append(vpath(vservers[0], rus[0], 0, 10e4*BANDWIDTH_SCALE, 1e-3*LATENCY_SCALE))
r_mmtc   = request(vservers, rus, vpaths, 0, 0, 500, [1e-2/MIPS_SCALE for p in V_P_S], [1 for q in V_P_R], [1e-3/BANDWIDTH_SCALE for e_p in E_P], 1e-2/BANDWIDTH_SCALE, 10/LATENCY_SCALE, 1e-1/MIPS_SCALE, 10, 0, 60)

vservers = []
vservers.append(vserver(6000*MIPS_SCALE, 5, [0,1,2,3,4])) ## Mobility management entity (MME)
rus      = [ru(1)]
vpaths   = []
vpaths.append(vpath(vservers[0], rus[0], 0, 10e9*BANDWIDTH_SCALE, 1e-3*LATENCY_SCALE))
r_embb   = request(vservers, rus, vpaths, 0, 1, 200, [1e-2/MIPS_SCALE for p in V_P_S], [1 for q in V_P_R], [1e-9/BANDWIDTH_SCALE for e_p in E_P], 1e-8/BANDWIDTH_SCALE, 10/LATENCY_SCALE, 1e-1/MIPS_SCALE, 10, 0, 50)

vservers = []
vservers.append(vserver(10000*MIPS_SCALE, 5, [0,1,2,3,4])) ## Mobility management entity (MME)
rus      = [ru(10)]
vpaths   = []
vpaths.append(vpath(vservers[0], rus[0], 0, 10e9*BANDWIDTH_SCALE, 1e-5*LATENCY_SCALE))
r_urll   = request(vservers, rus, vpaths, 1, 0, 2000, [1e-1/MIPS_SCALE for p in V_P_S], [10 for q in V_P_R], [1e-8/BANDWIDTH_SCALE for e_p in E_P], 1e-7/BANDWIDTH_SCALE, 100/LATENCY_SCALE, 1/MIPS_SCALE, 100, 100, 25)

vservers = []
vservers.append(vserver(16000*MIPS_SCALE, 5, [0,1,2,3,4])) ## Mobility management entity (MME)
rus      = [ru(10)]
vpaths   = []
vpaths.append(vpath(vservers[0], rus[0], 0, 10e9*BANDWIDTH_SCALE, 1e-5*LATENCY_SCALE))
r_mcri   = request(vservers, rus, vpaths, 2, 0, 10000, [1e-1/MIPS_SCALE for p in V_P_S], [10 for q in V_P_R], [1e-8/BANDWIDTH_SCALE for e_p in E_P], 1e6, 1e6, 1e6, 1e6, 1e6, 15)

slice_types = [r_embb, r_urll, r_mmtc, r_mcri]  # Network slice types
slice_probs = [0.7, 0.15, 0.1, 0.05]            # Probabilities for each type

slice_list  = []
slice_type_list  = []

# Seed for reproducibility (optional)
np.random.seed(42)

for iter in range(ITER):
    for t in range(SIMULATION_INTERVAL):
        slice_list.append(np.random.choice(slice_types, p=slice_probs))
        slice_type_list.append(slice_types.index(slice_list[-1]))

for iter in range(ITER):
    for t in range(SIMULATION_INTERVAL):
        print("iter", iter, slice_list[iter*SIMULATION_INTERVAL + t].gamma)

# %% [markdown]
# ## Infrastructure Graph Plot

# %%
plot_synth(V_P_S, V_P_R, E_P) if SYNTH_BRAIN == 0 else plot_brain(V_P_S, V_P_R, E_P)

# %%
print("############################ Optimal ############################")
profit_arr_opt = np.zeros(SIMULATION_INTERVAL*ITER)
violat_arr_opt = np.zeros(SIMULATION_INTERVAL*ITER)
migrat_arr_opt = np.zeros(SIMULATION_INTERVAL*ITER)
deploy_arr_opt = np.zeros(SIMULATION_INTERVAL*ITER)
reject_arr_opt = np.zeros((SIMULATION_INTERVAL*ITER,3))
time_arr_opt   = np.zeros(SIMULATION_INTERVAL*ITER)
print("############################ LP-Relaxed ############################")
profit_arr_cxr = np.zeros(SIMULATION_INTERVAL*ITER)
violat_arr_cxr = np.zeros(SIMULATION_INTERVAL*ITER)
migrat_arr_cxr = np.zeros(SIMULATION_INTERVAL*ITER)
deploy_arr_cxr = np.zeros(SIMULATION_INTERVAL*ITER)
reject_arr_cxr = np.zeros((SIMULATION_INTERVAL*ITER,3))
time_arr_cxr   = np.zeros(SIMULATION_INTERVAL*ITER)
print("############################ Ranking ############################")
profit_arr_grd = np.zeros(SIMULATION_INTERVAL*ITER)
violat_arr_grd = np.zeros(SIMULATION_INTERVAL*ITER)
migrat_arr_grd = np.zeros(SIMULATION_INTERVAL*ITER)
deploy_arr_grd = np.zeros(SIMULATION_INTERVAL*ITER)
reject_arr_grd = np.zeros((SIMULATION_INTERVAL*ITER,3))
time_arr_grd   = np.zeros(SIMULATION_INTERVAL*ITER)
print("############################ LP-Rounding ############################")
profit_arr_lpr = np.zeros(SIMULATION_INTERVAL*ITER)
violat_arr_lpr = np.zeros(SIMULATION_INTERVAL*ITER)
migrat_arr_lpr = np.zeros(SIMULATION_INTERVAL*ITER)
deploy_arr_lpr = np.zeros(SIMULATION_INTERVAL*ITER)
reject_arr_lpr = np.zeros((SIMULATION_INTERVAL*ITER,3))
time_arr_lpr   = np.zeros(SIMULATION_INTERVAL*ITER)
print("############################ Randomized-Rounding ############################")
profit_arr_rar = np.zeros(SIMULATION_INTERVAL*ITER)
violat_arr_rar = np.zeros(SIMULATION_INTERVAL*ITER)
migrat_arr_rar = np.zeros(SIMULATION_INTERVAL*ITER)
deploy_arr_rar = np.zeros(SIMULATION_INTERVAL*ITER)
reject_arr_rar = np.zeros((SIMULATION_INTERVAL*ITER,3))
time_arr_rar   = np.zeros(SIMULATION_INTERVAL*ITER)

type_arr       = np.zeros(SIMULATION_INTERVAL*ITER)
# Out:
# ############################ Optimal ############################
# ############################ LP-Relaxed ############################
# ############################ Ranking ############################
# ############################ LP-Rounding ############################
# ############################ Randomized-Rounding ############################

# %%
class TimeoutException(Exception):
    pass

def timeout_optimize(model):
    model.optimize()
    return model

def run_with_timeout(timeout, func, *args, **kwargs):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        future = executor.submit(func, *args, **kwargs)
        try:
            return future.result(timeout=timeout)
        except concurrent.futures.TimeoutError:
            raise TimeoutException("Timeout reached!")

# %% [markdown]
# ## Request Types

# %% [markdown]
# ## 5Guard

# %%
file_path = 'time.pkl'
if os.path.exists(file_path):
    with open(file_path, 'rb') as file:
        loaded_lists = pickle.load(file)
        t = loaded_lists[0]
else:
    t = 0

profit_arr_bst = np.zeros(SIMULATION_INTERVAL-t)
violat_arr_bst = np.zeros(SIMULATION_INTERVAL-t)
migrat_arr_bst = np.zeros(SIMULATION_INTERVAL-t)
deploy_arr_bst = np.zeros(SIMULATION_INTERVAL-t)
reject_arr_bst = np.zeros(SIMULATION_INTERVAL-t)
time_arr_bst   = np.zeros(SIMULATION_INTERVAL-t)

profit_arr_bst, reject_arr_bst, violat_arr_bst, migrat_arr_bst, deploy_arr_bst, time_arr_bst = fguard(slice_list)
# Out:
# Time 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 16
#      13 reject_arr_bst = np.zeros(SIMULATION_INTERVAL-t)
#      14 time_arr_bst   = np.zeros(SIMULATION_INTERVAL-t)
# ---> 16 profit_arr_bst, reject_arr_bst, violat_arr_bst, migrat_arr_bst, deploy_arr_bst, time_arr_bst = fguard(slice_list)
#
# File ~\5guard\algorithms\fguard.py:33, in fguard(slice_list)
#      31 for t in range(loaded_lists[0], SIMULATION_INTERVAL):
#      32     print("Time", t)
# ---> 33     r_t = copy.copy(slice_list[t])
#      34     reqs.append(r_t)
#      36     profit_opt, violat_opt, migrat_opt, deploy_opt, reject_opt, time_opt, X_t_opt, Y_t_opt, m_opt = optimal_iter(t, r_t, reqs, reqs_lp_t, X_t, Y_t, profit_arr_bst[t-int(loaded_lists[0])-1], "model_backup_opt.mps")
#
# IndexError: list index out of range

# %% [markdown]
# # Running the Simulation

# %%
print("############################ 5Guard ############################")

fiveguard()

# results = [profit_arr_bst[t:SIMULATION_INTERVAL-1], reject_arr_bst[t:SIMULATION_INTERVAL-1], violat_arr_bst[t:SIMULATION_INTERVAL-1], migrat_arr_bst[t:SIMULATION_INTERVAL-1], time_arr_bst[t:SIMULATION_INTERVAL-1]]
results = [profit_arr_bst, reject_arr_bst, violat_arr_bst, migrat_arr_bst, time_arr_bst]

file_path = 'saved_data/fiveguard.pkl'
if os.path.exists(file_path):
    with open(file_path, 'rb') as file:
        loaded_lists = pickle.load(file)
else:
    loaded_lists = []

if len(loaded_lists):
    for idx_list, list in enumerate(loaded_lists):
        loaded_lists[idx_list] = np.append(list, results[idx_list])
else:
    loaded_lists = results.copy()

# Save the lists to a file
with open('saved_data/fiveguard.pkl', 'wb') as file:
    pickle.dump(loaded_lists, file)

# Load the lists from the file
with open('saved_data/fiveguard_2.pkl', 'rb') as file:
    loaded_lists = pickle.load(file)

print(loaded_lists)
    
# Unpack the lists
profit_arr_bst, reject_arr_bst, violat_arr_bst, migrat_arr_bst, time_arr_bst = loaded_lists

# %%
# Unpack the lists
profit_arr_bst, reject_arr_bst, violat_arr_bst, migrat_arr_bst, time_arr_bst = loaded_lists

# %% [markdown]
# ## OPT

# %%
# print("############################ Optimal ############################")
# optimal()
# # Save the lists to a file
# with open('optimal.pkl', 'wb') as file:
#     pickle.dump([profit_arr_opt, reject_arr_opt, violat_arr_opt, migrat_arr_opt, time_arr_opt], file)

# Load the lists from the file
with open('saved_data/optimal_2.pkl', 'rb') as file:
    loaded_lists = pickle.load(file)

# Unpack the lists
profit_arr_opt, reject_arr_opt, violat_arr_opt, migrat_arr_opt, time_arr_opt = loaded_lists

# %% [markdown]
# ## IAR

# %%
# print("############################ Ranking ############################")
# ia_ranking()
# # Save the lists to a file
# with open('ranking.pkl', 'wb') as file:
#     pickle.dump([profit_arr_grd, reject_arr_grd, violat_arr_grd, migrat_arr_grd, time_arr_grd], file)

# Load the lists from the file
with open('saved_data/ranking_2.pkl', 'rb') as file:
    loaded_lists = pickle.load(file)

# Unpack the lists
profit_arr_grd, reject_arr_grd, violat_arr_grd, migrat_arr_grd, time_arr_grd = loaded_lists

# %% [markdown]
# ## DTR

# %%
# print("############################ LP-Rounding ############################")
# lp_round()
# # Save the lists to a file
# with open('lpr.pkl', 'wb') as file:
#     pickle.dump([profit_arr_lpr, reject_arr_lpr, violat_arr_lpr, migrat_arr_lpr, time_arr_lpr], file)

# Load the lists from the file
with open('saved_data/lpr_2.pkl', 'rb') as file:
    loaded_lists = pickle.load(file)

# Unpack the lists
profit_arr_lpr, reject_arr_lpr, violat_arr_lpr, migrat_arr_lpr, time_arr_lpr = loaded_lists

# %% [markdown]
# ## RNR

# %%
# print("############################ Randomized-Rounding ############################")
# random_round()
# # Save the lists to a file
# with open('rar.pkl', 'wb') as file:
#     pickle.dump([profit_arr_rar, reject_arr_rar, violat_arr_rar, migrat_arr_rar, time_arr_rar], file)

# Load the lists from the file
with open('saved_data/rar_2.pkl', 'rb') as file:
    loaded_lists = pickle.load(file)

# Unpack the lists
profit_arr_rar, reject_arr_rar, violat_arr_rar, migrat_arr_rar, time_arr_rar = loaded_lists

# %% [markdown]
# ## Results

# %%
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

xpoints  = range(0,SIMULATION_INTERVAL)
ypoints1 = [range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL)]
ypoints2 = [range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL)]
ypoints3 = [range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL)]
ypoints4 = [range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL)]
ypoints5 = [range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL)]
ypoints6 = [range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL),range(0,SIMULATION_INTERVAL)]

ypoints1[0] = profit_arr_grd
ypoints2[0] = profit_arr_lpr
ypoints3[0] = profit_arr_rar
ypoints4[0] = profit_arr_opt
ypoints6[0] = profit_arr_bst

ypoints1[1] = reject_arr_grd
ypoints2[1] = reject_arr_lpr
ypoints3[1] = reject_arr_rar
ypoints4[1] = reject_arr_opt
ypoints6[1] = reject_arr_bst

ypoints1[2] = violat_arr_grd
ypoints2[2] = violat_arr_lpr
ypoints3[2] = violat_arr_rar
ypoints4[2] = violat_arr_opt
ypoints6[2] = violat_arr_bst

# Get the cumulative sums for each iteration
cum_sum_migrat_arr_grd = np.cumsum(migrat_arr_grd, 0)
cum_sum_migrat_arr_lpr = np.cumsum(migrat_arr_lpr, 0)
cum_sum_migrat_arr_rar = np.cumsum(migrat_arr_rar, 0)
cum_sum_migrat_arr_opt = np.cumsum(migrat_arr_opt, 0)
cum_sum_migrat_arr_bst = np.cumsum(migrat_arr_bst, 0)
print(cum_sum_migrat_arr_grd, cum_sum_migrat_arr_lpr, cum_sum_migrat_arr_rar, cum_sum_migrat_arr_opt)

ypoints1[3] = cum_sum_migrat_arr_grd
ypoints2[3] = cum_sum_migrat_arr_lpr
ypoints3[3] = cum_sum_migrat_arr_rar
ypoints4[3] = cum_sum_migrat_arr_opt
ypoints6[3] = cum_sum_migrat_arr_bst

# ypoints1[4] = range(0,SIMULATION_INTERVAL)#deploy_arr_grd
# ypoints2[4] = range(0,SIMULATION_INTERVAL)#deploy_arr_lpr
# ypoints3[4] = range(0,SIMULATION_INTERVAL)#deploy_arr_rar
# ypoints4[4] = deploy_arr_opt
# ypoints6[4] = deploy_arr_opt

# Converged Average Task Delay
# delay_vect_avg1     = (sum(delay_vect[7191:8191]))/np.count_nonzero(delay_vect[7191:8191], axis = 0)
# delay_vect_avg1_off = (sum(delay_vect_off[7191:8191]))/np.count_nonzero(delay_vect_off[7191:8191], axis = 0)
# delay_vect_avg1_loc = (sum(delay_vect_loc[7191:8191]))/np.count_nonzero(delay_vect_loc[7191:8191], axis = 0)
# delay_vect_avg1_seq = (sum(delay_vect_seq[7191:8191]))/np.count_nonzero(delay_vect_seq[7191:8191], axis = 0)

# delay_vect_avg2     = (sum(delay_vect[15383:16383]))/np.count_nonzero(delay_vect[15383:16383], axis = 0)
# delay_vect_avg2_off = (sum(delay_vect_off[15383:16383]))/np.count_nonzero(delay_vect_off[15383:16383], axis = 0)
# delay_vect_avg2_loc = (sum(delay_vect_loc[15383:16383]))/np.count_nonzero(delay_vect_loc[15383:16383], axis = 0)
# delay_vect_avg2_seq = (sum(delay_vect_seq[15383:16383]))/np.count_nonzero(delay_vect_seq[15383:16383], axis = 0)

# delay_vect_avg3     = (sum(delay_vect[23575:24575]))/np.count_nonzero(delay_vect[23575:24575], axis = 0)
# delay_vect_avg3_off = (sum(delay_vect_off[23575:24575]))/np.count_nonzero(delay_vect_off[23575:24575], axis = 0)
# delay_vect_avg3_loc = (sum(delay_vect_loc[23575:24575]))/np.count_nonzero(delay_vect_loc[23575:24575], axis = 0)
# delay_vect_avg3_seq = (sum(delay_vect_seq[23575:24575]))/np.count_nonzero(delay_vect_seq[23575:24575], axis = 0)

barWidth  = 0.13
markevery = 10
linewidth = 5
tick_label_size = 25
legend_font_size = 18
xlabel_font_size = 23
ylabel_font_size = 23
marker_size = 17
markeredgewidth = 4

plot_titles = [
    ('$\it{t}$', 'Profit'),
    ('Isolation Level', 'Slice Admission (%)'),
    ('$\it{t}$', 'Aggregate Violation Cost'),
    ('$\it{t}$', 'Cumulative Migration'),
]

for i in range(4):
    if i == 1:
        fig, ax = plt.subplots(figsize=(7, 6))
        br1 = np.arange(3)
        br2 = [x + barWidth for x in br1]
        br3 = [x + barWidth for x in br2]
        br4 = [x + barWidth for x in br3]
        br5 = [x + barWidth for x in br4]
        
        # Colors chosen for distinguishability in color and black & white
        colors = ["#646464", "#EE0000", "#6E8EE6", "#21CD7D", "#00FF00"]#['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

        # Patterns for each bar group
        patterns = ['/', '\\', 'O', '-', '...']
        
        ax.bar(br1, (1-np.sum(np.array(ypoints1[1]), axis=0)/[0.7,0.2,0.1]/SIMULATION_INTERVAL)*100+1, width=barWidth, color=colors[0], edgecolor='black', hatch=patterns[0])  # Greedy 
        ax.bar(br2, (1-np.sum(np.array(ypoints2[1]), axis=0)/[0.7,0.2,0.1]/SIMULATION_INTERVAL)*100+1, width=barWidth, color=colors[1], edgecolor='black', hatch=patterns[1])  # Det-Round
        ax.bar(br3, (1-np.sum(np.array(ypoints3[1]), axis=0)/[0.7,0.2,0.1]/SIMULATION_INTERVAL)*100+1, width=barWidth, color=colors[2], edgecolor='black', hatch=patterns[2])  # Rnd-Round
        ax.bar(br4, (1-np.sum(np.array(ypoints4[1]), axis=0)/[0.7,0.2,0.1]/SIMULATION_INTERVAL)*100+1, width=barWidth, color=colors[3], edgecolor='black', hatch=patterns[3])  # Optimal
        ax.bar(br5, (1-np.sum(np.array(ypoints6[1]), axis=0)/[0.7,0.2,0.1]/SIMULATION_INTERVAL)*100+1, width=barWidth, color=colors[4], edgecolor='black', hatch=patterns[4])  # 5Guard
        
        ax.set_xticks([r + 2*barWidth for r in range(3)])
        ax.set_xticklabels(['0', '1', '2'])

        ax.tick_params(axis='x', labelsize=tick_label_size)
        ax.tick_params(axis='y', labelsize=tick_label_size)
        
        ax.legend(['IAR', 'DTR', 'RNR', 'OPT', '5Guard'], fontsize=legend_font_size-3.1, loc='upper center', ncol=3)
        
        ax.set_xlabel(plot_titles[i][0], fontsize=xlabel_font_size)
        ax.set_ylabel(plot_titles[i][1], fontsize=ylabel_font_size)
        
        fig.tight_layout(pad=0.5)

        plt.ylim(top=119)

        # Get the current y-ticks and labels
        yticks = plt.gca().get_yticks()
        ytick_labels = [item.get_text() for item in plt.gca().get_yticklabels()]
        
        # Remove the last two y-tick labels
        ytick_labels[-1] = ''
        
        # Set the modified y-tick labels back
        plt.gca().set_yticklabels(ytick_labels)
        
        plt.savefig(f"result_{i+4}.svg", format="svg")
    else:
        fig, ax = plt.subplots(figsize=(7, 6))
        
        ax.plot(xpoints, ypoints1[i][0:SIMULATION_INTERVAL], marker='o', markevery=markevery, markersize=marker_size, color="#646464", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#646464", markeredgewidth=markeredgewidth)
        ax.plot(xpoints, ypoints2[i][0:SIMULATION_INTERVAL], marker='v', markevery=markevery, markersize=marker_size, color="#EE0000", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#EE0000", markeredgewidth=markeredgewidth)
        ax.plot(xpoints, ypoints3[i][0:SIMULATION_INTERVAL], marker='h', markevery=markevery, markersize=marker_size, color="#6E8EE6", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#6E8EE6", markeredgewidth=markeredgewidth)
        ax.plot(xpoints, ypoints4[i][0:SIMULATION_INTERVAL], marker='^', markevery=markevery, markersize=marker_size, color="#21CD7D", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#21CD7D", markeredgewidth=markeredgewidth)
        ax.plot(xpoints, ypoints6[i][0:SIMULATION_INTERVAL], marker='D', markevery=markevery, markersize=marker_size, color="#00FF00", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#00FF00", markeredgewidth=markeredgewidth)
        ax.grid()
    
        ax.tick_params(axis='x', labelsize=tick_label_size)
        ax.tick_params(axis='y', labelsize=tick_label_size)
        
        ax.legend(['IAR','DTR','RNR','OPT','5Guard'], fontsize=legend_font_size)
        ax.set_xlabel(plot_titles[i][0], fontsize=xlabel_font_size)
        ax.set_ylabel(plot_titles[i][1], fontsize=ylabel_font_size)

        # Set scientific notation for y-axis
        if i != 3:
            formatter = ScalarFormatter(useMathText=True)
            formatter.set_scientific(True)
            formatter.set_powerlimits((-1, 1))
            ax.yaxis.set_major_formatter(formatter)
        
        plt.xticks(np.arange(0, SIMULATION_INTERVAL, step=10))  # Adjust step as needed for your data
        
        fig.tight_layout(pad=0.5)
        plt.savefig(f"result_{i+4}.svg", format="svg")

plt.show()

# %%
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

xpoints = range(0, SIMULATION_INTERVAL)
ypoints1 = [range(0, SIMULATION_INTERVAL)]
ypoints2 = [range(0, SIMULATION_INTERVAL)]
ypoints3 = [range(0, SIMULATION_INTERVAL)]
ypoints4 = [range(0, SIMULATION_INTERVAL)]
ypoints5 = [range(0, SIMULATION_INTERVAL)]
ypoints6 = [range(0, SIMULATION_INTERVAL)]

ypoints1[0] = time_arr_grd
ypoints2[0] = time_arr_lpr
ypoints3[0] = time_arr_rar
ypoints4[0] = time_arr_opt
ypoints6[0] = time_arr_bst

print(time_arr_grd)

barWidth = 0.5
markevery = 10
linewidth = 5
tick_label_size = 25
legend_font_size = 18
xlabel_font_size = 25
ylabel_font_size = 25
marker_size = 17
markeredgewidth = 4

plot_titles = ('$\it{t}$', 'Allocation Time (sec.)')

fig, ax = plt.subplots(figsize=(10, 4.75))

ax.plot(xpoints, ypoints1[0][0:SIMULATION_INTERVAL], marker='o', markevery=markevery, markersize=marker_size, color="#646464", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#646464", markeredgewidth=markeredgewidth)
ax.plot(xpoints, ypoints2[0][0:SIMULATION_INTERVAL], marker='v', markevery=markevery, markersize=marker_size, color="#EE0000", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#EE0000", markeredgewidth=markeredgewidth)
ax.plot(xpoints, ypoints3[0][0:SIMULATION_INTERVAL], marker='h', markevery=markevery, markersize=marker_size, color="#6E8EE6", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#6E8EE6", markeredgewidth=markeredgewidth)
ax.plot(xpoints, ypoints4[0][0:SIMULATION_INTERVAL], marker='^', markevery=markevery, markersize=marker_size, color="#21CD7D", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#21CD7D", markeredgewidth=markeredgewidth)
ax.plot(xpoints, ypoints6[0][0:SIMULATION_INTERVAL], marker='D', markevery=markevery, markersize=marker_size, color="#00FF00", linewidth=linewidth, markerfacecolor='none', markeredgecolor="#00FF00", markeredgewidth=markeredgewidth)

# Add dashed lines for the limits
limits = [60, 50, 25, 15]
for limit in limits:
    ax.axhline(y=limit, color='#000000', linestyle='--', linewidth=2)

ax.grid()

ax.tick_params(axis='x', labelsize=tick_label_size)
ax.tick_params(axis='y', labelsize=tick_label_size)

ax.legend(['IAR','DTR','RNR','OPT','5Guard'], fontsize=legend_font_size)
ax.set_xlabel(plot_titles[0], fontsize=xlabel_font_size)
ax.set_ylabel(plot_titles[1], fontsize=ylabel_font_size)

# Set scientific notation for y-axis
# formatter = ScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1, 1))
# ax.yaxis.set_major_formatter(formatter)

plt.xticks(np.arange(0, SIMULATION_INTERVAL, step=10))  # Adjust step as needed for your data

fig.tight_layout(pad=0.5)
plt.savefig(f"result_{8}.svg", format="svg")

plt.show()

# %%
# # Save the lists to a file
# with open('time.pkl', 'wb') as file:
#     pickle.dump([0, [], [], []], file)
