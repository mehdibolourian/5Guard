# %%
from libraries import *

# %% [markdown]
# # Simulation Setup

# %%
# Parameters for simulation
ITER                    = 2                                 # Iteration count
SIMULATION_INTERVAL     = 30                                # Simulation interval per iteration
TOT_SIMULATION_INTERVAL = max(100, SIMULATION_INTERVAL)     # Total simulation interval
T_START                 = 30                                # Starting time step

SYNTH_BRAIN             = 0                                 # Whether to choose the synthetic topology (0) or BRAIN (1)

gp.setParam("OutputFlag", 0)                                # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-18

# %% [markdown]
# ### 5G Infrastructure Setup

# %%
V_P_S = V_P_R = E_P = E_P_l = L = L_pqi = []
V_P_S, V_P_R, E_P, E_P_l, L, L_pqi = init_setup_synth() if SYNTH_BRAIN == 0 else init_setup_brain()

# %% [markdown]
# ### Slice Request Setup

# %%
# Initialize slice types and probabilities
sr_types = create_sr_resources()
sr_probs = [0.7, 0.15, 0.1, 0.05]  # Probabilities for each type

# Generate SR list
sr_list, sr_type_list = init_setup_sr(ITER, TOT_SIMULATION_INTERVAL, sr_types, sr_probs)

# %% [markdown]
# ### Infrastructure Graph

# %%
plot_synth(V_P_S, V_P_R, E_P) if SYNTH_BRAIN == 0 else plot_brain(V_P_S, V_P_R, E_P)

# %% [markdown]
# ### Data Templates

# %%
data = {}

algs = ["fgr", "opt", "iar", "dtr", "rnr", "nis"]
for a in algs:
    data[a] = {
        "profit":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "violat":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 5)), ## 5 for Total (0), Radio (1), Bandwidth (2), MIPS (3), and Delay (4)
        "migrat":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "deploy":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 4)),
        "overhe":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 4)),
        "reseff":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 4)),
        "reject":  np.zeros((ITER, T_START+SIMULATION_INTERVAL, 3)),
        "time":    np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "vars":    [[{} for _ in range(T_START+SIMULATION_INTERVAL)] for _ in range(ITER)],
        "feasib":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "timeou":  np.zeros((ITER, T_START+SIMULATION_INTERVAL)),
        "R_t":     [[[] for _ in range(T_START+SIMULATION_INTERVAL)] for _ in range(ITER)]
    }

# %% [markdown]
# # Running the Simulation

# %% [markdown]
# ### Saved Data Reuse (from previous runs)

# %%
keys = ["profit", "violat", "migrat", "deploy", "overhe", "reseff", "reject", "time", "vars", "feasib", "timeou", "R_t"]
data_loaded = {}
if T_START > 0:
    for a in algs:
        # Load the lists from the file
        with open(f'saved_data/{a}.pkl', 'rb') as file:
            data_loaded = pickle.load(file)
        
        data[a]["profit"][:, :T_START]    = data_loaded["profit"][:, :T_START]
        data[a]["violat"][:, :T_START, :] = data_loaded["violat"][:, :T_START, :]
        data[a]["migrat"][:, :T_START]    = data_loaded["migrat"][:, :T_START]
        data[a]["deploy"][:, :T_START, :] = data_loaded["deploy"][:, :T_START, :]
        data[a]["overhe"][:, :T_START, :] = data_loaded["overhe"][:, :T_START, :]
        data[a]["reseff"][:, :T_START, :] = data_loaded["reseff"][:, :T_START, :]
        data[a]["reject"][:, :T_START, :] = data_loaded["reject"][:, :T_START, :]
        data[a]["time"][:, :T_START]      = data_loaded["time"][:, :T_START]
        data[a]["feasib"][:, :T_START]    = data_loaded["feasib"][:, :T_START]
        data[a]["timeou"][:, :T_START]    = data_loaded["timeou"][:, :T_START]
        
        # Handle dictionaries and lists separately
        for i in range(ITER):
            for t in range(T_START):
                data[a]["vars"][i][t] = data_loaded["vars"][i][t]
                data[a]["R_t"][i][t]  = data_loaded["R_t"][i][t]

# %% [markdown]
# ### Simulation Run Template

# %%
def run_simulation(alg, ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, func, limit=None):
    """
    Generic simulation function for different algorithms
    
    Parameters:
        alg (str): "fgr", "opt", "iar", "dtr", "rnr"
        ITER (int): Number of iterations
        SIMULATION_INTERVAL (int): Simulation time steps
        sr_list (list): Service request list
        V_P_S, V_P_R, E_P, E_P_l, L, L_pqi: Network elements
        func (function): Optimization function to call (opt_iter or dtr_iter)
        limit (float, optional): Limit parameter for "dtr" algorithm
    """
    file_path = f'saved_data/{alg}.pkl'
    
    for iter in range(ITER):
        if T_START == 0:
            m = gp.Model("e2esliceiso")
            if alg == "fgr":
                m.write(f'saved_model/model_backup_fgr_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_opt_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_iar_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_dtr_{iter}.mps')
                m.write(f'saved_model/model_backup_fgr_rnr_{iter}.mps')
            else:
                m.write(f'saved_model/model_backup_{alg}_{iter}.mps')
        
        for t in range(T_START, T_START+SIMULATION_INTERVAL):
            print(f"\niteration: {iter}, Time step: {t}")
            
            prev_profit = data[alg]["profit"][iter][t-1] if t > 0 else 0
            prev_R_t = data[alg]["R_t"][iter][t-1] if t > 0 else []
            
            if alg == "fgr":    # "dtr" requires an additional limit parameter
                result = func(limit, prev_profit, iter, t, sr_list[iter * SIMULATION_INTERVAL + t], prev_R_t, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi)
            elif alg == "dtr":  # "dtr" requires an additional limit parameter + f_fgr = 0
                result = func(limit, prev_profit, iter, t, sr_list[iter * SIMULATION_INTERVAL + t], prev_R_t, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, 0)
            else:
                result = func(prev_profit, iter, t, sr_list[iter * SIMULATION_INTERVAL + t], prev_R_t, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, 0)
            
            keys = ["profit", "violat", "migrat", "deploy", "overhe", "reseff", "reject", "time", "vars", "feasib", "timeou", "R_t"]
            
            if result[9] == 1:  # feasible
                for idx_k, k in enumerate(keys):
                    data[alg][k][iter][t] = result[idx_k]
            else:  # infeasible
                if t > 0:
                    for idx_k, k in enumerate(keys):
                        data[alg][k][iter][t] = data[alg][k][iter][t-1]
                    data[alg]["reject"][iter][t] = result[6]
                    data[alg]["time"][iter][t]   = result[7]
                    data[alg]["feasib"][iter][t] = result[9]
                    data[alg]["timeou"][iter][t] = result[10]
    
    # Save updated data
    with open(file_path, 'wb') as file:
        pickle.dump(data[alg], file)
    
    return data

# %% [markdown]
# ## OPT

# %%
data = run_simulation("opt", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, opt_iter)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 382.813385107355   |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.13636363636364 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4805.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.004835844039916992 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | OPT                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (1, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 5942.035607329577     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0069925785064697266 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 930.6363636363636     |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | OPT                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 6424.848992436932     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0075533390045166016 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 930.7727272727273     |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6907.662377544288    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010000467300415039 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7390.475762651642    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015719175338745117 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0454545454545    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7873.2891477589965   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.016213417053222656 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.1818181818182    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.024240970611572266 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8752.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015549659729003906 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.3636363636364    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 9
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 9889.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015627145767211914 |
# +-------------------------+----------------------+
# | Overhead Cost           | 1761.8636363636365   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 10
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 10371.87036292574  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0187075138092041 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1762.0             |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 11
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 12
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 11408.87036292574   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03289365768432617 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.5              |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 13
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 11891.683748033094  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03125262260437012 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.6363636363635  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 14
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 12374.497133140449 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0319368839263916 |
# +-------------------------+--------------------+
# | Overhead Cost           | 2692.772727272727  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 15
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12857.310518247803  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04761552810668945 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2692.909090909091   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 16
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13340.12390335516   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03777503967285156 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.0454545454545  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 17
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13822.937288462517  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03125429153442383 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.181818181818   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 18
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 14305.750673569872  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04762840270996094 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.318181818182   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 19
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | OPT                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 14788.154954227635            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03214311599731445           |
# +---------------------------+-------------------------------+
# | MIPS Violation Cost       | -2.600195024626828e-06        |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -2.3646862246096135e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 2693.863652244314             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 20
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 15271.377443784582   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.044382572174072266 |
# +-------------------------+----------------------+
# | Overhead Cost           | 2693.590909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 21
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 15754.190828891937  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04524374008178711 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.727272727273   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 22
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 16237.004213999291  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04750180244445801 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2693.8636363636365  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 23
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 16719.817599106646 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0458376407623291 |
# +-------------------------+--------------------+
# | Overhead Cost           | 2694.0             |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 24
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 17202.630984214     |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06318998336791992 |
# +-------------------------+---------------------+
# | Overhead Cost           | 2694.1363636363635  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 25
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 18331.858256941272  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06291580200195312 |
# +-------------------------+---------------------+
# | Overhead Cost           | 3532.409090909091   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 26
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 18812.626187503174 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0617222785949707 |
# +-------------------------+--------------------+
# | Overhead Cost           | 3534.590909090909  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 27
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | OPT                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 19294.212299883256            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.07289552688598633           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 3535.9545454545455            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 28
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 19776.61659408152   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06338047981262207 |
# +-------------------------+---------------------+
# | Overhead Cost           | 3536.5              |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 29
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 20258.2027064616   |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0747983455657959 |
# +-------------------------+--------------------+
# | Overhead Cost           | 3537.8636363636365 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 0
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 382.813385107355   |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.13636363636364 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 865.62677021471      |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015621662139892578 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.27272727272728   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 1348.4401553220648   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015547037124633789 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.4090909090909    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 1744.3946002740977   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.008508682250976562 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.45454545454545   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 6166.616822496321    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.023540496826171875 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.45454545454545   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 7303.61682249632     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015611410140991211 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.9545454545455    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7786.430207603676    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.013099193572998047 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0909090909091    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8269.243592711031   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.02367234230041504 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.2272727272727   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8752.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.016989946365356445 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.3636363636364    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 9
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 9234.87036292574    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01600813865661621 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.5               |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 10
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 9717.683748033094    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015077829360961914 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.6363636363636    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 11
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 10200.497133140449  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03121185302734375 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.7727272727273   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 12
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 10683.310518247805  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.02622079849243164 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.9090909090909   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 13
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | OPT                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 11079.310417745293   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.031342267990112305 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 14
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 11562.123802852648  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01610565185546875 |
# +-------------------------+---------------------+
# | Overhead Cost           | 932.0454545454545   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 15
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 12044.937187960002 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0320124626159668 |
# +-------------------------+--------------------+
# | Overhead Cost           | 932.1818181818182  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 16
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 12527.750573067357 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.033721923828125  |
# +-------------------------+--------------------+
# | Overhead Cost           | 932.3181818181818  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 17
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13010.563958174711  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03169584274291992 |
# +-------------------------+---------------------+
# | Overhead Cost           | 932.4545454545455   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 18
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13493.377343282065  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03626251220703125 |
# +-------------------------+---------------------+
# | Overhead Cost           | 932.5909090909091   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 19
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | OPT                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13976.190728389423 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0311737060546875 |
# +-------------------------+--------------------+
# | Overhead Cost           | 932.7272727272727  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 20
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0216496 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 21
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 15013.190728389425  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.10999393463134766 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1863.2272727272727  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 22
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0935366 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 23
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.114785 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 24
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 15496.00411349678   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08925485610961914 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1863.3636363636365  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 25
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0780439 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 26
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 15978.817498604134  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.13251662254333496 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1863.5              |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 27
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 16461.63088371149   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.08985543251037598 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1863.6363636363635  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 28
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 16944.444268818843  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.10301685333251953 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1863.7727272727273  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 29
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | OPT                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 17427.257653926197  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.09687066078186035 |
# +-------------------------+---------------------+
# | Overhead Cost           | 1863.909090909091   |
# +-------------------------+---------------------+

# %% [markdown]
# ## DTR

# %%
LIMIT = 0.5
data = run_simulation("dtr", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, dtr_iter, limit=LIMIT)
# Out:
# iteration: 0, Time step: 0
# m.objVal:382.8133851073551, profit_opt: 382.813385107355
# +-------------------------+------------------------+
# | Category                | Value                  |
# +=========================+========================+
# | Algorithm               | DTR                    |
# +-------------------------+------------------------+
# | Request Isolation Level | (0, 1)                 |
# +-------------------------+------------------------+
# | Profit                  | 382.813385107355       |
# +-------------------------+------------------------+
# | Allocation Time         | 0.00026679039001464844 |
# +-------------------------+------------------------+
# | Overhead Cost           | 100.13636363636364     |
# +-------------------------+------------------------+
#
# iteration: 0, Time step: 1
# m.objVal:4805.035607337952, profit_opt: 4805.035607329577
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4805.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015555143356323242 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 2
# m.objVal:5942.035607337952, profit_opt: 5942.035607329577
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5942.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.007078409194946289 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.6363636363636    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 3
# m.objVal:6424.848992422223, profit_opt: 6424.848992436932
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | DTR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 6424.848992436932   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.00414729118347168 |
# +-------------------------+---------------------+
# | Overhead Cost           | 930.7727272727273   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 4
# m.objVal:6907.662377521396, profit_opt: 6907.662377544288
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6907.662377544288    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.013948440551757812 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 5
# m.objVal:7390.475762605667, profit_opt: 7390.475762651642
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | DTR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 7390.475762651642 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 931.0454545454545 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 6
# m.objVal:7873.28914770484, profit_opt: 7873.2891477589965
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7873.2891477589965   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.021345853805541992 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.1818181818182    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 7
# m.objVal:8269.243592649698, profit_opt: 8269.243592711031
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.018413066864013672 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# m.objVal:8752.05697774887, profit_opt: 8752.056977818385
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | DTR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8752.056977818385   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01125192642211914 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.3636363636364   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 9
# m.objVal:9889.05697774887, profit_opt: 9889.056977818385
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (1, 0)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9889.056977818385             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.01563429832458496           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1761.8636363636365            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 10
# m.objVal:10371.870362833142, profit_opt: 10371.87036292574
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10371.87036292574             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.0065762996673583984         |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.0                        |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 11
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 12
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0248764 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 13
# m.objVal:10854.683747932315, profit_opt: 10854.683748033094
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10854.683748033094            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.015717029571533203          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.1363636363635            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 14
# m.objVal:11337.497133016586, profit_opt: 11337.497133140449
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11337.497133140449            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03134417533874512           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.2727272727273            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 15
# m.objVal:11820.310518115759, profit_opt: 11820.310518247803
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 11820.310518247803            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03378605842590332           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.409090909091             |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 16
# m.objVal:12303.123903214931, profit_opt: 12303.12390335516
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12303.12390335516             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.032253265380859375          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.5454545454545            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 17
# m.objVal:12785.937288299203, profit_opt: 12785.937288462515
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12785.937288462515            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.015644311904907227          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458566e-13 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 1762.6818181818182            |
# +---------------------------+-------------------------------+
#
# iteration: 0, Time step: 18
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0313358 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 19
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0317955 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 20
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0398893 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 21
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0318727 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 22
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0466003 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 23
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0339031 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 24
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0313528 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 25
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 1        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.031811 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 26
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0334151 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 27
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0279706 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 28
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |  0      |
# +-----------------------------+---------+
# | Request Isolation Sub-level |  1      |
# +-----------------------------+---------+
# | Allocation Time             |  0.0172 |
# +-----------------------------+---------+
# | Feasible                    |  0      |
# +-----------------------------+---------+
# | Timeout                     |  0      |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 29
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0356202 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 0
# m.objVal:382.8133851073551, profit_opt: 382.813385107355
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | DTR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 382.813385107355   |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.13636363636364 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 1
# m.objVal:865.6267702147102, profit_opt: 865.62677021471
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | DTR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 865.62677021471    |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.27272727272728 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 2
# m.objVal:1348.4401553220646, profit_opt: 1348.4401553220648
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | DTR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 1348.4401553220648 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.4090909090909  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 3
# m.objVal:1744.3946002740977, profit_opt: 1744.3946002740977
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | DTR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 1744.3946002740977 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.45454545454545 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 4
# m.objVal:6166.616822496057, profit_opt: 6166.616822496321
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 6166.616822496321    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.013212919235229492 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.45454545454545   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 5
# m.objVal:7303.616822496057, profit_opt: 7303.61682249632
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | DTR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (1, 0)            |
# +-------------------------+-------------------+
# | Profit                  | 7303.61682249632  |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 930.9545454545455 |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 6
# m.objVal:7786.430207580328, profit_opt: 7786.430207603676
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7786.430207603676    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.016121625900268555 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0909090909091    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 7
# m.objVal:8269.2435926795, profit_opt: 8269.243592711031
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.013504505157470703 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 8
# m.objVal:8752.056977778673, profit_opt: 8752.056977818385
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | DTR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8752.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.020209550857543945 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.3636363636364    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 9
# m.objVal:9234.870362862945, profit_opt: 9234.870362925742
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 9234.870362925742             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.015619277954101562          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.2732925824820995e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.5                         |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 10
# m.objVal:9717.683747962117, profit_opt: 9717.683748033096
# +---------------------------+------------------------------+
# | Category                  | Value                        |
# +===========================+==============================+
# | Algorithm                 | DTR                          |
# +---------------------------+------------------------------+
# | Request Isolation Level   | (0, 1)                       |
# +---------------------------+------------------------------+
# | Profit                    | 9717.683748033096            |
# +---------------------------+------------------------------+
# | Allocation Time           | 0.022002696990966797         |
# +---------------------------+------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.455191522836685e-12 |
# +---------------------------+------------------------------+
# | Overhead Cost             | 931.6363636363636            |
# +---------------------------+------------------------------+
#
# iteration: 1, Time step: 11
# m.objVal:10200.497133046389, profit_opt: 10200.49713314045
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10200.49713314045             |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.013045787811279297          |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.6370904631912707e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.7727272727273             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 12
# m.objVal:10683.310518145561, profit_opt: 10683.310518247807
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | DTR                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 10683.310518247807            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.03132152557373047           |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8189894035458563e-12 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 931.9090909090909             |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 13
# m.objVal:11079.310417637229, profit_opt: 11079.310417745293
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 0)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 11079.310417745293          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.03167533874511719         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 931.9090909090909           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 14
# m.objVal:11562.123802736402, profit_opt: 11562.123802852648
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 11562.123802852648          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.016574382781982422        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 932.0454545454545           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 15
# m.objVal:12044.937187820673, profit_opt: 12044.937187960002
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 12044.937187960002          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.03742384910583496         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 932.1818181818182           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 16
# m.objVal:12527.750572919846, profit_opt: 12527.750573067357
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 12527.750573067357          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.015697479248046875        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 932.3181818181818           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 17
# m.objVal:13010.563958004117, profit_opt: 13010.563958174711
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 13010.563958174711          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.030214786529541016        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 932.4545454545455           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 18
# m.objVal:13493.37734310329, profit_opt: 13493.377343282065
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 13493.377343282065          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.027449369430541992        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 932.5909090909091           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 19
# m.objVal:13976.190728202462, profit_opt: 13976.190728389423
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 13976.190728389423          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.03171825408935547         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 932.7272727272727           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 20
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 2        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 0        |
# +-----------------------------+----------+
# | Allocation Time             | 0.015553 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 21
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0360267 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 22
# Infeasible rounding with infeasible constraints: [6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0480604 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 23
# Infeasible rounding with infeasible constraints: [6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0482075 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 24
# m.objVal:14459.004113286734, profit_opt: 14459.004113496778
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 14459.004113496778          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.03339338302612305         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 932.8636363636364           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 25
# Infeasible rounding with infeasible constraints: [6]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0474131 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 26
# m.objVal:14941.817498385906, profit_opt: 14941.817498604132
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 14941.817498604132          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.03163480758666992         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 933.0                       |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 27
# m.objVal:15424.630883470178, profit_opt: 15424.630883711487
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 15424.630883711487          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.04827451705932617         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 933.1363636363636           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 28
# m.objVal:15907.44426856935, profit_opt: 15907.444268818843
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 15907.444268818843          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.044938087463378906        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 933.2727272727273           |
# +---------------------------+-----------------------------+
#
# iteration: 1, Time step: 29
# m.objVal:16390.257653668523, profit_opt: 16390.257653926197
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | DTR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 16390.257653926197          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.031246423721313477        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 933.4090909090909           |
# +---------------------------+-----------------------------+

# %% [markdown]
# ## RNR

# %%
data = run_simulation("rnr", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, rnr_iter)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 382.813385107355    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.00464177131652832 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.13636363636364  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4805.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010077238082885742 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5942.035607329577    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.010971307754516602 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.6363636363636    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | RNR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 6424.848992436932 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 930.7727272727273 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6907.662377544288    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015567779541015625 |
# +-------------------------+----------------------+
# | Overhead Cost           | 930.9090909090909    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7390.475762651642    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015408754348754883 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.0454545454545    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 7873.2891477589965  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01485753059387207 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.1818181818182   |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.008608341217041016 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8752.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.017124652862548828 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.3636363636364    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 9
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (1, 0)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 9889.055992818385           |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.014007329940795898        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, 0.0009949999999662397 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1761.8636363636365          |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 10
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 10371.86937792574           |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.035215139389038086        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, 0.0009949999999662397 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1762.0                      |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 11
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0156255 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 12
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0161636 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 13
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 10854.682763033094          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.031247615814208984        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, 0.0009949999999662397 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1762.1363636363635          |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 14
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0261395 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 15
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 11337.496148140448          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.007493257522583008        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, 0.0009949999999662397 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1762.2727272727273          |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 16
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 11820.309533247804          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.015630006790161133        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, 0.0009949999999662397 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1762.409090909091           |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 17
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0539496 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 18
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0259783 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 19
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 12303.12291835516           |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.030243635177612305        |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, 0.0009949999999662397 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1762.5454545454545          |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 20
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0469596 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 21
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0426137 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 22
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0316377 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 23
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | RNR                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 12785.936303462515          |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.01874542236328125         |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, 0.0009949999999662397 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 1762.6818181818182          |
# +---------------------------+-----------------------------+
#
# iteration: 0, Time step: 24
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.045176 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 25
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0469549 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 26
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.041461 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 0, Time step: 27
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0317988 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 28
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0293267 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 0, Time step: 29
# Infeasible rounding with infeasible constraints: [4]
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0259318 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 0
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 382.813385107355     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.001039266586303711 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.13636363636364   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 865.62677021471      |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015004396438598633 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.27272727272728   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 1348.4401553220648   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.002337217330932617 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.4090909090909    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 1744.3946002740977   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015630483627319336 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.45454545454545   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 6166.616822496321    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.019489288330078125 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.45454545454545   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | RNR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (1, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 7303.61682249632      |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0065174102783203125 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 930.9545454545455     |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | RNR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 7786.430207603676   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01787877082824707 |
# +-------------------------+---------------------+
# | Overhead Cost           | 931.0909090909091   |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8269.243592711031    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.014256954193115234 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.2272727272727    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | RNR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8752.056977818385    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015797138214111328 |
# +-------------------------+----------------------+
# | Overhead Cost           | 931.3636363636364    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 9
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0271511 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 10
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0166271 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 11
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0312545 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 12
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0331395 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 13
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0314519 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 14
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0244622 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 15
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0196676 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 16
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0125875 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 17
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0240335 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 18
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0226345 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 19
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0301511 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 20
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 2         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0150812 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 21
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 1         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0314562 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 22
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0321383 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 23
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0156336 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 24
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0313294 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 25
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 0         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0156288 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 26
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0179768 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 27
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0245616 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+
#
# iteration: 1, Time step: 28
# +-----------------------------+----------+
# | Category                    |    Value |
# +=============================+==========+
# | Request Isolation Level     | 0        |
# +-----------------------------+----------+
# | Request Isolation Sub-level | 1        |
# +-----------------------------+----------+
# | Allocation Time             | 0.031328 |
# +-----------------------------+----------+
# | Feasible                    | 0        |
# +-----------------------------+----------+
# | Timeout                     | 0        |
# +-----------------------------+----------+
#
# iteration: 1, Time step: 29
# +-----------------------------+-----------+
# | Category                    |     Value |
# +=============================+===========+
# | Request Isolation Level     | 0         |
# +-----------------------------+-----------+
# | Request Isolation Sub-level | 1         |
# +-----------------------------+-----------+
# | Allocation Time             | 0.0179615 |
# +-----------------------------+-----------+
# | Feasible                    | 0         |
# +-----------------------------+-----------+
# | Timeout                     | 0         |
# +-----------------------------+-----------+

# %% [markdown]
# ## IAR

# %%
data = run_simulation("iar", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, iar_iter)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 381.5861123800822  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0019989013671875 |
# +-------------------------+--------------------+
# | Overhead Cost           | 101.36363636363637 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (2, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 4803.808334603906     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0038802623748779297 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 101.36363636363637    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (1, 0)            |
# +-------------------------+-------------------+
# | Profit                  | 5940.808334603906 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 931.8636363636364 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 6422.394446969032     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0019176006317138672 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 933.2272727272727     |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+------------------+
# | Category                | Value            |
# +=========================+==================+
# | Algorithm               | IAR              |
# +-------------------------+------------------+
# | Request Isolation Level | (0, 1)           |
# +-------------------------+------------------+
# | Profit                  | 6903.98055934906 |
# +-------------------------+------------------+
# | Allocation Time         | 0.0              |
# +-------------------------+------------------+
# | Overhead Cost           | 934.590909090909 |
# +-------------------------+------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 7385.566671729088 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 935.9545454545455 |
# +-------------------------+-------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 7867.152784109116     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0021011829376220703 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 937.3181818181818     |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 8262.698138147593    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.001990079879760742 |
# +-------------------------+----------------------+
# | Overhead Cost           | 937.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8744.28425051272     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.001957416534423828 |
# +-------------------------+----------------------+
# | Overhead Cost           | 939.1363636363636    |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 9
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (1, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 9881.28425051272      |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0017445087432861328 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1769.6363636363635    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 10
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 10362.870362892747 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1771.0             |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 11
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000001C04E92C5D0> of SR <data.sr object at 0x000001C04C02F5D0>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 12
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 1          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00195503 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 0, Time step: 13
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 10844.456475272775   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.002050161361694336 |
# +-------------------------+----------------------+
# | Overhead Cost           | 1772.3636363636365   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 14
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 11326.042587637901    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0010077953338623047 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1773.7272727272727    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 15
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 11807.628700017929 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1775.090909090909  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 16
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 12289.214812397957 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 1776.4545454545455 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 17
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 12709.437288418412 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 68.18181818181782  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1777.8181818181818 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 18
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 13124.750673517585    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0030031204223632812 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 141.8181818181818     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1779.1818181818182    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 19
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13540.064058631659 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 215.4545454545451  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1780.5454545454545 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 20
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13955.377443745732 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 289.0909090909091  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1781.909090909091  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 21
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 14370.690828859806    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0011937618255615234 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 362.7272727272724     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1783.2727272727273    |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 22
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 14786.004213958979 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 436.3636363636357  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1784.6363636363635 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 23
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 15201.317599073052 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 509.9999999999997  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1786.0             |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 24
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 15616.630984187126 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 583.6363636363637  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1787.3636363636365 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 25
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       1 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 0, Time step: 26
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | IAR                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 16031.944369286299  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.00411534309387207 |
# +-------------------------+---------------------+
# | MIPS Violation Cost     | 657.272727272727    |
# +-------------------------+---------------------+
# | Overhead Cost           | 1788.7272727272727  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 27
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 16447.257754400373 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 730.9090909090903  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1790.090909090909  |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 28
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 16862.571139514446 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 804.5454545454543  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1791.4545454545455 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 29
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 17277.88452462852  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 878.1818181818176  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1792.8181818181818 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 0
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 381.5861123800822     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0010917186737060547 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 101.36363636363637    |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 863.1722247601645     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0013630390167236328 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 102.72727272727272    |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 1344.758337140247  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 104.09090909090908 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 1740.3036911831891   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.016137123107910156 |
# +-------------------------+----------------------+
# | Overhead Cost           | 104.54545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (2, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 6162.525913402438  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 104.54545454545453 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (1, 0)            |
# +-------------------------+-------------------+
# | Profit                  | 7299.525913402438 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 935.0454545454545 |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 7781.112025782466 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 936.4090909090909 |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 8262.698138162494    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015878915786743164 |
# +-------------------------+----------------------+
# | Overhead Cost           | 937.7727272727273    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 8744.28425052762      |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0011491775512695312 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 939.1363636363636     |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 9
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 9225.870362907648 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 940.5             |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 10
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 9707.456475287676 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 941.8636363636364 |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 11
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 10189.042587652802    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0008096694946289062 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 943.2272727272727     |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 12
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 10670.62870003283 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 944.590909090909  |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 13
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 11066.628599524498 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 944.590909090909   |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 14
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 11548.214711904526    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0029947757720947266 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 945.9545454545455     |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 15
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 12029.800824284554   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.014508485794067383 |
# +-------------------------+----------------------+
# | Overhead Cost           | 947.3181818181818    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 16
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 12511.38693664968    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015556097030639648 |
# +-------------------------+----------------------+
# | Overhead Cost           | 948.6818181818182    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 17
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 12992.973049029708   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.005586147308349609 |
# +-------------------------+----------------------+
# | Overhead Cost           | 950.0454545454545    |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 18
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 13474.559161409736    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0030112266540527344 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 951.4090909090909     |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 19
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 13956.145273789763 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 952.7727272727273  |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 20
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000001C04EF447D0> of SR <data.sr object at 0x000001C04EF44610>
# Infeasible Problem
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       2 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 1, Time step: 21
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 14874.690728366375   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.002077341079711914 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 242.72727272727255   |
# +-------------------------+----------------------+
# | Overhead Cost           | 1783.2727272727273   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 22
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       0 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 1, Time step: 23
# +-----------------------------+------------+
# | Category                    |      Value |
# +=============================+============+
# | Request Isolation Level     | 0          |
# +-----------------------------+------------+
# | Request Isolation Sub-level | 0          |
# +-----------------------------+------------+
# | Allocation Time             | 0.00235176 |
# +-----------------------------+------------+
# | Feasible                    | 0          |
# +-----------------------------+------------+
# | Timeout                     | 0          |
# +-----------------------------+------------+
#
# iteration: 1, Time step: 24
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 15290.004113450646 |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 316.3636363636358  |
# +-------------------------+--------------------+
# | Overhead Cost           | 1784.6363636363635 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 25
# +-----------------------------+---------+
# | Category                    |   Value |
# +=============================+=========+
# | Request Isolation Level     |       0 |
# +-----------------------------+---------+
# | Request Isolation Sub-level |       0 |
# +-----------------------------+---------+
# | Allocation Time             |       0 |
# +-----------------------------+---------+
# | Feasible                    |       0 |
# +-----------------------------+---------+
# | Timeout                     |       0 |
# +-----------------------------+---------+
#
# iteration: 1, Time step: 26
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | IAR                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 15705.31749856472  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | MIPS Violation Cost     | 389.99999999999983 |
# +-------------------------+--------------------+
# | Overhead Cost           | 1786.0             |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 27
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | IAR                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 16120.630883678794   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.003300905227661133 |
# +-------------------------+----------------------+
# | MIPS Violation Cost     | 463.63636363636385   |
# +-------------------------+----------------------+
# | Overhead Cost           | 1787.3636363636365   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 28
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | IAR                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 16535.944268792868    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0015041828155517578 |
# +-------------------------+-----------------------+
# | MIPS Violation Cost     | 537.2727272727271     |
# +-------------------------+-----------------------+
# | Overhead Cost           | 1788.7272727272727    |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 29
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | IAR               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 16951.25765390694 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | MIPS Violation Cost     | 610.9090909090904 |
# +-------------------------+-------------------+
# | Overhead Cost           | 1790.090909090909 |
# +-------------------------+-------------------+

# %% [markdown]
# ## 5Guard

# %%
data = run_simulation("fgr", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, fgr_iter, limit=LIMIT)

# Load the lists from the file
with open('saved_data/fgr.pkl', 'rb') as file:
    data_loaded = pickle.load(file)
# Out:
# iteration: 0, Time step: 0
# m.objVal:382.8133851073551, profit_opt: 382.813385107355
# arr:[382.8134 381.5861 382.8134 382.8134]
# alg:opt
#
# iteration: 0, Time step: 1
# m.objVal:4805.035607337952, profit_opt: 4805.035607329577
# arr:[4805.0356 4803.8083 4805.0356 4805.0356]
# alg:opt
#
# iteration: 0, Time step: 2
# m.objVal:5942.035607337952, profit_opt: 5942.035607329577
# arr:[5942.0356 5940.8083 5942.0356 5942.0356]
# alg:opt
#
# iteration: 0, Time step: 3
# m.objVal:6424.848992422223, profit_opt: 6424.848992436932
# arr:[6424.849  6422.3944 6424.849  6424.849 ]
# alg:opt
#
# iteration: 0, Time step: 4
# m.objVal:6907.662377521396, profit_opt: 6907.662377544288
# arr:[6907.6624 6903.9806 6907.6624 6907.6624]
# alg:opt
#
# iteration: 0, Time step: 5
# m.objVal:7390.475762605667, profit_opt: 7390.475762651642
# arr:[7390.4758 7385.5667 7390.4758 7390.4758]
# alg:opt
#
# iteration: 0, Time step: 6
# m.objVal:7873.28914770484, profit_opt: 7873.2891477589965
# arr:[7873.2891 7867.1528 7873.2891 7873.2891]
# alg:opt
#
# iteration: 0, Time step: 7
# m.objVal:8269.243592649698, profit_opt: 8269.243592711031
# arr:[8269.2436 8262.6981 8269.2436 8269.2436]
# alg:opt
#
# iteration: 0, Time step: 8
# m.objVal:8752.05697774887, profit_opt: 8752.056977818385
# arr:[8752.057  8744.2843 8752.057  8752.057 ]
# alg:opt
#
# iteration: 0, Time step: 9
# m.objVal:9889.05697774887, profit_opt: 9889.056977818385
# arr:[9889.057  9881.2843 9889.057  8899.1082]
# alg:opt
#
# iteration: 0, Time step: 10
# m.objVal:10371.870362833142, profit_opt: 10371.87036292574
# arr:[10371.8704 10362.8704 10371.8704     0.    ]
# alg:opt
#
# iteration: 0, Time step: 11
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000001C04E92C5D0> of SR <data.sr object at 0x000001C04C02F5D0>
# Infeasible Problem
# arr:[0 0 0 0]
# alg:opt
#
# iteration: 0, Time step: 12
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[11408.8704     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 13
# Infeasible rounding with infeasible constraints: [4]
# arr:[11891.6837     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 14
# Infeasible rounding with infeasible constraints: [4]
# arr:[12374.4971     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 15
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[12857.3105     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 16
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[13340.1239     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 17
# Infeasible rounding with infeasible constraints: [4]
# arr:[13822.9373     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 18
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[14305.7507     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 19
# Infeasible rounding with infeasible constraints: [4]
# arr:[14788.155     0.        0.        0.   ]
# alg:opt
#
# iteration: 0, Time step: 20
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[15271.3774     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 21
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[15754.1908     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 22
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[16237.0042     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 23
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[16719.8176     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 24
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[17202.631     0.        0.        0.   ]
# alg:opt
#
# iteration: 0, Time step: 25
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[18331.8583     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 26
# Infeasible rounding with infeasible constraints: [4]Infeasible rounding with infeasible constraints: [4]
#
# arr:[18812.6262     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 27
# Infeasible rounding with infeasible constraints: [4]
# arr:[19294.2123     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 28
# Infeasible rounding with infeasible constraints: [4]
# arr:[19776.6166     0.         0.         0.    ]
# alg:opt
#
# iteration: 0, Time step: 29
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[20258.2027     0.         0.         0.    ]
# alg:opt
#
# iteration: 1, Time step: 0
# m.objVal:382.8133851073551, profit_opt: 382.813385107355
# arr:[382.8134 381.5861 382.8134 382.8134]
# alg:opt
#
# iteration: 1, Time step: 1
# m.objVal:865.6267702147102, profit_opt: 865.62677021471
# arr:[865.6268 863.1722 865.6268 865.6268]
# alg:opt
#
# iteration: 1, Time step: 2
# m.objVal:1348.4401553220646, profit_opt: 1348.4401553220648
# arr:[1348.4402 1344.7583 1348.4402 1348.4402]
# alg:opt
#
# iteration: 1, Time step: 3
# m.objVal:1744.3946002740977, profit_opt: 1744.3946002740977
# arr:[1744.3946 1740.3037 1744.3946 1744.3946]
# alg:opt
#
# iteration: 1, Time step: 4
# m.objVal:6166.616822496057, profit_opt: 6166.616822496321
# arr:[6166.6168 6162.5259 6166.6168 6166.6168]
# alg:opt
#
# iteration: 1, Time step: 5
# m.objVal:7303.616822496057, profit_opt: 7303.61682249632
# arr:[7303.6168 7299.5259 7303.6168 7303.6168]
# alg:opt
#
# iteration: 1, Time step: 6
# m.objVal:7786.430207580328, profit_opt: 7786.430207603676
# arr:[7786.4302 7781.112  7786.4302 7786.4302]
# alg:opt
#
# iteration: 1, Time step: 7
# m.objVal:8269.2435926795, profit_opt: 8269.243592711031
# arr:[8269.2436 8262.6981 8269.2436 8269.2436]
# alg:opt
#
# iteration: 1, Time step: 8
# m.objVal:8752.056977778673, profit_opt: 8752.056977818385
# arr:[8752.057  8744.2843 8752.057  8752.057 ]
# alg:opt
#
# iteration: 1, Time step: 9
# m.objVal:9234.870362862945, profit_opt: 9234.870362925742
# arr:[9234.8704 9225.8704 9234.8704    0.    ]
# alg:opt
#
# iteration: 1, Time step: 10
# m.objVal:9717.683747962117, profit_opt: 9717.683748033096
# arr:[9717.6837 9707.4565 9717.6837    0.    ]
# alg:opt
#
# iteration: 1, Time step: 11
# m.objVal:10200.497133046389, profit_opt: 10200.49713314045
# arr:[10200.4971 10189.0426 10200.4971     0.    ]
# alg:opt
#
# iteration: 1, Time step: 12
# m.objVal:10683.310518145561, profit_opt: 10683.310518247807
# arr:[10683.3105 10670.6287 10683.3105     0.    ]
# alg:opt
#
# iteration: 1, Time step: 13
# m.objVal:11079.310417637229, profit_opt: 11079.310417745293
# arr:[11079.3104 11066.6286 11079.3104     0.    ]
# alg:opt
#
# iteration: 1, Time step: 14
# m.objVal:11562.123802736402, profit_opt: 11562.123802852648
# arr:[11562.1238 11548.2147 11562.1238     0.    ]
# alg:opt
#
# iteration: 1, Time step: 15
# m.objVal:12044.937187820673, profit_opt: 12044.937187960002
# arr:[12044.9372 12029.8008 12044.9372     0.    ]
# alg:opt
#
# iteration: 1, Time step: 16
# m.objVal:12527.750572919846, profit_opt: 12527.750573067357
# arr:[12527.7506 12511.3869 12527.7506     0.    ]
# alg:opt
#
# iteration: 1, Time step: 17
# m.objVal:13010.563958004117, profit_opt: 13010.563958174711
# arr:[13010.564 12992.973 13010.564     0.   ]
# alg:opt
#
# iteration: 1, Time step: 18
# m.objVal:13493.37734310329, profit_opt: 13493.377343282065
# arr:[13493.3773 13474.5592 13493.3773     0.    ]
# alg:opt
#
# iteration: 1, Time step: 19
# m.objVal:13976.190728202462, profit_opt: 13976.190728389423
# arr:[13976.1907 13956.1453 13976.1907     0.    ]
# alg:opt
#
# iteration: 1, Time step: 20
# infeasible: No remaining NR-BS for mapping RU <data.ru object at 0x000001C04EF447D0> of SR <data.sr object at 0x000001C04EF44610>
# Infeasible Problem
# arr:[0 0 0 0]
# alg:opt
#
# iteration: 1, Time step: 21
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[15013.1907 14874.6907     0.         0.    ]
# alg:opt
#
# iteration: 1, Time step: 22
# Infeasible rounding with infeasible constraints: [2 4 6 8]
# Infeasible rounding with infeasible constraints: [3 4]
# arr:[0 0 0 0]
# alg:opt
#
# iteration: 1, Time step: 23
# Infeasible rounding with infeasible constraints: [3 4]
# Infeasible rounding with infeasible constraints: [2 4 6 8]
# arr:[0 0 0 0]
# alg:opt
#
# iteration: 1, Time step: 24
# Infeasible rounding with infeasible constraints: [4]
# arr:[15496.0041 15290.0041     0.         0.    ]
# alg:opt
#
# iteration: 1, Time step: 25
# Infeasible rounding with infeasible constraints: [2 4 6 8]
# Infeasible rounding with infeasible constraints: [3 4 6]
# arr:[0 0 0 0]
# alg:opt
#
# iteration: 1, Time step: 26
# Infeasible rounding with infeasible constraints: [4]
# arr:[15978.8175 15705.3175     0.         0.    ]
# alg:opt
#
# iteration: 1, Time step: 27
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[16461.6309 16120.6309     0.         0.    ]
# alg:opt
#
# iteration: 1, Time step: 28
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[16944.4443 16535.9443     0.         0.    ]
# alg:opt
#
# iteration: 1, Time step: 29
# Infeasible rounding with infeasible constraints: [4]
# Infeasible rounding with infeasible constraints: [4]
# arr:[17427.2577 16951.2577     0.         0.    ]
# alg:opt

# %% [markdown]
# ## NIS

# %%
data = run_simulation("nis", ITER, T_START, SIMULATION_INTERVAL, sr_list, V_P_S, V_P_R, E_P, E_P_l, L, L_pqi, nis_iter)

# Load the lists from the file
with open('saved_data/nis.pkl', 'rb') as file:
    data_loaded = pickle.load(file)
# Out:
# iteration: 0, Time step: 0
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | NIS                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 382.9497487437186     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0036780834197998047 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.0                 |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 1
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | NIS                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (2, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 846.8994974874372     |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0069828033447265625 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.0                 |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 2
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 1326.8894472361808   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.012998104095458984 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.0                |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 3
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | NIS                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 1)                |
# +-------------------------+-----------------------+
# | Profit                  | 1809.8391959798996    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0069997310638427734 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.0                 |
# +-------------------------+-----------------------+
#
# iteration: 0, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 2292.788944723618    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015641450881958008 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.0                |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 2775.738693467337    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.021493911743164062 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.0                |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3258.688442211055    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.011921882629394531 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.0                |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 3654.6428871630883   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.013150453567504883 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 8
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | NIS                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 1)             |
# +-------------------------+--------------------+
# | Profit                  | 4137.592635906806  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0                |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.04545454545453 |
# +-------------------------+--------------------+
#
# iteration: 0, Time step: 9
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 4617.58258565555     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.014600753784179688 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 10
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 5100.532334399269    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015732288360595703 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 11
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 5564.482083142987    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.025477170944213867 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 12
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 6044.472032891731    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.016707658767700195 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 13
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 6527.421781635449    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015691518783569336 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 14
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 7010.371530379168   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03169393539428711 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 15
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7493.321279122887    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.022553443908691406 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 16
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 7976.271027866605   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03839993476867676 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 17
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8459.220776610326   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01573657989501953 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 18
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8942.170525354044   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03499555587768555 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 19
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 9425.120274097762    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.030147790908813477 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 20
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 9908.07002284148     |
# +-------------------------+----------------------+
# | Allocation Time         | 0.039231061935424805 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 21
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 10391.0197715852    |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01573038101196289 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 22
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 10873.969520328917   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015703439712524414 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 23
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 11356.919269072636   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.038570404052734375 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 24
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 11839.869017816354  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03143787384033203 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 25
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 12319.858967565098   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.031672000885009766 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 0, Time step: 26
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12802.808716308817  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03979659080505371 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 27
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13285.758465052537  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03315281867980957 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 28
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13768.708213796255  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04756331443786621 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 0, Time step: 29
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 14251.657962539974  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04392743110656738 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 0
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 382.9497487437186    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015735626220703125 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.0                |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 1
# +-------------------------+-------------------+
# | Category                | Value             |
# +=========================+===================+
# | Algorithm               | NIS               |
# +-------------------------+-------------------+
# | Request Isolation Level | (0, 1)            |
# +-------------------------+-------------------+
# | Profit                  | 865.8994974874372 |
# +-------------------------+-------------------+
# | Allocation Time         | 0.0               |
# +-------------------------+-------------------+
# | Overhead Cost           | 100.0             |
# +-------------------------+-------------------+
#
# iteration: 1, Time step: 2
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 1348.8492462311558  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01574110984802246 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.0               |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 3
# +-------------------------+-----------------------+
# | Category                | Value                 |
# +=========================+=======================+
# | Algorithm               | NIS                   |
# +-------------------------+-----------------------+
# | Request Isolation Level | (0, 0)                |
# +-------------------------+-----------------------+
# | Profit                  | 1744.8036911831887    |
# +-------------------------+-----------------------+
# | Allocation Time         | 0.0030879974365234375 |
# +-------------------------+-----------------------+
# | Overhead Cost           | 100.04545454545453    |
# +-------------------------+-----------------------+
#
# iteration: 1, Time step: 4
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (2, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 2208.7534399269075   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015624284744262695 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 5
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (1, 0)               |
# +-------------------------+----------------------+
# | Profit                  | 2688.743389675651    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.011270761489868164 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 6
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3171.6931384193695   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.016010046005249023 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 7
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 3654.6428871630883   |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015633583068847656 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 8
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 4137.592635906806    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015086650848388672 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 9
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 4620.542384650525    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015697956085205078 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 10
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 5103.492133394244    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015558958053588867 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 11
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 5586.441882137962    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015697717666625977 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 12
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 6069.391630881681   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03125119209289551 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 13
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | NIS                |
# +-------------------------+--------------------+
# | Request Isolation Level | (0, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 6465.391530379168  |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0294644832611084 |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.04545454545453 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 14
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 6948.341279122887   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.01912212371826172 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 15
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7431.291027866605    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.030709505081176758 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 16
# +-------------------------+----------------------+
# | Category                | Value                |
# +=========================+======================+
# | Algorithm               | NIS                  |
# +-------------------------+----------------------+
# | Request Isolation Level | (0, 1)               |
# +-------------------------+----------------------+
# | Profit                  | 7914.240776610324    |
# +-------------------------+----------------------+
# | Allocation Time         | 0.015630483627319336 |
# +-------------------------+----------------------+
# | Overhead Cost           | 100.04545454545453   |
# +-------------------------+----------------------+
#
# iteration: 1, Time step: 17
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8397.190525354043   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03645730018615723 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 18
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 8880.140274097763   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06278514862060547 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 19
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 9363.090022841481   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03315448760986328 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 20
# +-------------------------+--------------------+
# | Category                | Value              |
# +=========================+====================+
# | Algorithm               | NIS                |
# +-------------------------+--------------------+
# | Request Isolation Level | (2, 0)             |
# +-------------------------+--------------------+
# | Profit                  | 9827.0397715852    |
# +-------------------------+--------------------+
# | Allocation Time         | 0.0437016487121582 |
# +-------------------------+--------------------+
# | Overhead Cost           | 100.04545454545453 |
# +-------------------------+--------------------+
#
# iteration: 1, Time step: 21
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (1, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 10307.029721333944  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04686713218688965 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 22
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 10703.02962083143   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.03511929512023926 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 23
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 11099.029520328919  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06260418891906738 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 24
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 11581.979269072637  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.04729962348937988 |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 25
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 0)              |
# +-------------------------+---------------------+
# | Profit                  | 11770.979168570124  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.12089228630065918 |
# +-------------------------+---------------------+
# | Radio Violation Cost    | 230.0               |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 26
# +---------------------------+-------------------------------+
# | Category                  | Value                         |
# +===========================+===============================+
# | Algorithm                 | NIS                           |
# +---------------------------+-------------------------------+
# | Request Isolation Level   | (0, 1)                        |
# +---------------------------+-------------------------------+
# | Profit                    | 12253.928917332032            |
# +---------------------------+-------------------------------+
# | Allocation Time           | 0.1097252368927002            |
# +---------------------------+-------------------------------+
# | Radio Violation Cost      | 230.0                         |
# +---------------------------+-------------------------------+
# | Bandwidth Violation Costs | 0, 0, -1.8190621631219986e-08 |
# +---------------------------+-------------------------------+
# | Overhead Cost             | 100.04545454545453            |
# +---------------------------+-------------------------------+
#
# iteration: 1, Time step: 27
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 12746.87866605756   |
# +-------------------------+---------------------+
# | Allocation Time         | 0.05886983871459961 |
# +-------------------------+---------------------+
# | Radio Violation Cost    | 220.0               |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 28
# +-------------------------+---------------------+
# | Category                | Value               |
# +=========================+=====================+
# | Algorithm               | NIS                 |
# +-------------------------+---------------------+
# | Request Isolation Level | (0, 1)              |
# +-------------------------+---------------------+
# | Profit                  | 13239.828414801279  |
# +-------------------------+---------------------+
# | Allocation Time         | 0.06570601463317871 |
# +-------------------------+---------------------+
# | Radio Violation Cost    | 210.0               |
# +-------------------------+---------------------+
# | Overhead Cost           | 100.04545454545453  |
# +-------------------------+---------------------+
#
# iteration: 1, Time step: 29
# +---------------------------+-----------------------------+
# | Category                  | Value                       |
# +===========================+=============================+
# | Algorithm                 | NIS                         |
# +---------------------------+-----------------------------+
# | Request Isolation Level   | (0, 1)                      |
# +---------------------------+-----------------------------+
# | Profit                    | 13792.778163545             |
# +---------------------------+-----------------------------+
# | Allocation Time           | 0.15368270874023438         |
# +---------------------------+-----------------------------+
# | Radio Violation Cost      | 140.0                       |
# +---------------------------+-----------------------------+
# | Bandwidth Violation Costs | 0, 0, -5.45696821063757e-13 |
# +---------------------------+-----------------------------+
# | Overhead Cost             | 100.04545454545453          |
# +---------------------------+-----------------------------+

# %% [markdown]
# # Results

# %% [markdown]
# ### Find the data average and error bars

# %%
data_avg = copy.deepcopy(data)

kpis = ["profit", "violat", "migrat", "deploy", "overhe", "reseff", "reject", "time"]

for a in algs:
    for k in kpis:
        data_avg[a][k]  = np.sum(data[a][k], axis=0) / ITER

# %% [markdown]
# ### Plot Settings

# %%
plt.rcParams['font.family']  = 'DeJavu Serif'
plt.rcParams['font.serif']   = ['Times New Roman']
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype']  = 42

# Constants
bar_width       = 0.13
markevery       = 10
linewidth       = 5
marker_size     = 17
markeredgewidth = 4
step            = 5  # Error bars frequency

tick_label_size, legend_font_size, xlabel_font_size, ylabel_font_size = 25, 18, 23, 23

kpi1  = ["reject"]
kpis2 = ["profit", "migrat"]
kpis3 = ["violat", "deploy", "overhe", "reseff"]
kpi4  = ["time"]
kpi5  = ["isol"]

xpoints = range(0, T_START+SIMULATION_INTERVAL)
ypoints = data_avg.copy()
yerrors_low  = {a: {k: ypoints[a][k]-np.min(data[a][k], axis=0) for k in kpis2+kpis3+kpi4} for a in algs}  # Lower bound errors
yerrors_high = {a: {k: np.max(data[a][k], axis=0)-ypoints[a][k] for k in kpis2+kpis3+kpi4} for a in algs}  # Upper bound errors

plot_titles = [
    ('Isolation Level', 'Slice Admission (%)'),
    ('$\it{t}$', 'Profit'),
    ('$\it{t}$', 'Cumulative Migration'),
    ('$\it{t}$', 'Aggregate Violation Cost'),   
    ('$\it{t}$', 'Aggregate Deployment Cost'),
    ('$\it{t}$', 'Aggregate Overhead Cost'),
    ('$\it{t}$', 'Resource Efficiency (%)'),
    ('$\it{t}$', 'Average Isolation Level'),
]

colors     = ["#646464", "#EE0000", "#6E8EE6", "#21CD7D", "#00FF00", "#EEEE00"]
markers    = ['o', 'v', 'h', '^', 'D', '>']
linestyles = ['-', '-', '-', '-', '-', '--']

patterns = ['/', '\\', 'O', '-', '...', '.']

# %% [markdown]
# ## Slice Admission

# %%
fig, ax = plt.subplots(figsize=(7, 6))
positions = [np.arange(3) + i * bar_width for i in range(len(algs))]

for i, alg in enumerate(algs):
    NUM_L0_SR = sr_type_list.count(0) + sr_type_list.count(2)
    NUM_L1_SR = sr_type_list.count(1)
    NUM_L2_SR = sr_type_list.count(3)
    denominator = np.clip([NUM_L0_SR, NUM_L1_SR, NUM_L2_SR], 1e-9, None)
    
    values = (1 - np.sum(np.array(ypoints[alg]["reject"]), axis=0) / denominator) * 100
    values = [min(a, b) for a, b in zip(values, [100, 100, 100])]

    # Extracting error values
    err_low  = values - list([np.min((1 - np.sum(np.array(data[alg]["reject"]), axis=1) / denominator), axis=0) * 100])[0]
    err_high = list([np.max((1 - np.sum(np.array(data[alg]["reject"]), axis=1) / denominator), axis=0) * 100])[0] - values

    if alg == 'nis':
        for j in range(1,3):
            values[j]   = 1 # For visibility
            err_low[j]  = 0 # For visibility
            err_high[j] = 0 # For visibility
    
    # Adding bars with error bars
    ax.bar(positions[i], values, width=bar_width, color=colors[i], edgecolor='black', hatch=patterns[i], linestyle=linestyles[i],
           yerr=[err_low, err_high], capsize=5, error_kw={'elinewidth': 3, 'capthick': 1.5, 'capsize': 4})

ax.set_xticks(positions[2])
ax.set_xticklabels(['0', '1', '2'])
ax.set_ylim(top=119)

ax.tick_params(axis='both', labelsize=tick_label_size)
ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR', 'NIS'], fontsize=legend_font_size-3, loc='upper center', ncol=3)

ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.yaxis.get_major_formatter().set_scientific(True)
ax.yaxis.get_major_formatter().set_powerlimits((-1, 1))
ax.yaxis.offsetText.set_fontsize(20)  # Adjust font size

ax.set_xlabel(plot_titles[0][0], fontsize=xlabel_font_size)
ax.set_ylabel(plot_titles[0][1], fontsize=ylabel_font_size)
fig.tight_layout(pad=0.5)
plt.savefig(f"plots/result_{0}.svg", format="svg")

# %% [markdown]
# ## Profit and Cumulative Migration

# %%
for idx_k, k in enumerate(kpis2):
    fig, ax = plt.subplots(figsize=(7, 6))

    for i, alg in enumerate(algs):
        ax.errorbar(xpoints, ypoints[alg][k],  
                    yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerrors_low[alg][k], np.nan),  
                          np.where(np.arange(len(xpoints)) % step == 0, yerrors_high[alg][k], np.nan)),  
                    marker=markers[i], markevery=markevery, markersize=marker_size,
                    color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
                    markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle=linestyles[i])
    ax.grid()
    
    plt.xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))

    ax.tick_params(axis='both', labelsize=tick_label_size)
    ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR', 'NIS'], fontsize=legend_font_size)

    ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    ax.yaxis.get_major_formatter().set_scientific(True)
    ax.yaxis.get_major_formatter().set_powerlimits((-1, 1))
    ax.yaxis.offsetText.set_fontsize(20)  # Adjust font size
    
    ax.set_xlabel(plot_titles[idx_k+1][0], fontsize=xlabel_font_size)
    ax.set_ylabel(plot_titles[idx_k+1][1], fontsize=ylabel_font_size)
    fig.tight_layout(pad=0.5)
    plt.savefig(f"plots/result_{idx_k+1}.svg", format="svg")

# %% [markdown]
# ## Allocation Time

# %%
xpoints = range(0, T_START+SIMULATION_INTERVAL)
kpi     = "time"
limits  = np.array([4, 5, 1, 0.5])*0.01

# Plot setup
fig, ax = plt.subplots(figsize=(10, 4.75))
for i, alg in enumerate(algs):
    ax.errorbar(xpoints, ypoints[alg][kpi],  
                    yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerrors_low[alg][kpi], np.nan),  
                          np.where(np.arange(len(xpoints)) % step == 0, yerrors_high[alg][kpi], np.nan)),  
                    marker=markers[i], markevery=markevery, markersize=marker_size,
                    color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
                    markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle=linestyles[i])
    

# Formatting
ax.grid()
ax.tick_params(axis='both', labelsize=25)
ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR', 'NIS'], fontsize=18)
ax.set_xlabel('$\it{t}$', fontsize=25)
ax.set_ylabel('Allocation Time (sec.)', fontsize=25)
ax.set_xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))

# Add dashed limit lines
for limit in limits:
    ax.axhline(y=limit, color='#000000', linestyle='--', linewidth=2)
    
fig.tight_layout(pad=0.5)

# Save & show
plt.savefig("plots/result_8.svg", format="svg")
plt.show()

# %% [markdown]
# ## Violation, Deployment, and Overhead Costs and Resource Efficiency

# %%
for idx_k, k in enumerate(kpis3):
    fig, ax = plt.subplots(figsize=(7, 6))
    
    for i, alg in enumerate(algs):
        ax.errorbar(xpoints, ypoints[alg][k][:,0],  
                    yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerrors_low[alg][k][:,0], np.nan),  
                          np.where(np.arange(len(xpoints)) % step == 0, yerrors_high[alg][k][:,0], np.nan)),  
                    marker=markers[i], markevery=markevery, markersize=marker_size,
                    color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
                    markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle=linestyles[i])
    ax.grid()
    
    plt.xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))

    ax.tick_params(axis='both', labelsize=tick_label_size)
    ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR', 'NIS'], fontsize=legend_font_size)

    if k != "reseff": ## Percentage data
        ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        ax.yaxis.get_major_formatter().set_scientific(True)
        ax.yaxis.get_major_formatter().set_powerlimits((-1, 1))
        ax.yaxis.offsetText.set_fontsize(20)  # Adjust font size
    
    ax.set_xlabel(plot_titles[idx_k+3][0], fontsize=xlabel_font_size)
    ax.set_ylabel(plot_titles[idx_k+3][1], fontsize=ylabel_font_size)
    fig.tight_layout(pad=0.5)
    plt.savefig(f"plots/result_{idx_k+3}.svg", format="svg")

plt.show()

# %% [markdown]
# ## Average Isolation Level

# %%
def cumulative_average_with_holding(values):
    cumulative_sum = 0
    count = 0
    avg_list = []
    
    for v in values:
        if v != -1:  # Only update sum and count for valid values
            cumulative_sum += v
            count += 1
        avg_list.append(cumulative_sum / count if count > 0 else 0)  # Maintain last valid average

    return avg_list

## Calculating the cumulative average isolation level:
isol_level         = [{} for iter in range(ITER)]
isol_level_avg     = {}
isol_level_avg_avg = {}
for alg in algs:
    for iter in range(ITER):
        gamma_values          = [0 if type == 0 or type == 2
                                 else (1 if type == 1 else 2)
                                 for type in sr_type_list[iter*TOT_SIMULATION_INTERVAL : iter*TOT_SIMULATION_INTERVAL+T_START+SIMULATION_INTERVAL]
                                ]
        isol_level[iter][alg] = [0 if alg == 'nis'
                                 else (gamma_values[t % TOT_SIMULATION_INTERVAL]
                                       if data[alg]["feasib"][iter][t % TOT_SIMULATION_INTERVAL] == 1
                                       else -1) # Exclusing infeasible cases
                                 for t in range(iter*TOT_SIMULATION_INTERVAL, iter*TOT_SIMULATION_INTERVAL+T_START+SIMULATION_INTERVAL)
                                ]

    # Compute cumulative average for each algorithm
    isol_level_avg[alg] = [cumulative_average_with_holding(isol_level[i][alg]) for i in range(ITER)] 

for a in algs:
    isol_level_avg_avg[a]  = np.sum(isol_level_avg[a], axis=0) / ITER # Avergae over iterations

# %%
fig, ax   = plt.subplots(figsize=(7, 6))

yerr_low  = {a: isol_level_avg_avg[a]-np.min(isol_level_avg[a], axis=0) for a in algs}  # Lower bound errors
yerr_high = {a: np.max(isol_level_avg[a], axis=0)-isol_level_avg_avg[a] for a in algs}  # Upper bound errors

for i, alg in enumerate(algs):
    ax.errorbar(xpoints, isol_level_avg_avg[alg],  
                yerr=(np.where(np.arange(len(xpoints)) % step == 0, yerr_low[alg], np.nan),  
                      np.where(np.arange(len(xpoints)) % step == 0, yerr_high[alg], np.nan)),  
                marker=markers[i], markevery=markevery, markersize=marker_size,
                color=colors[i], linewidth=linewidth, markerfacecolor='none', markeredgecolor=colors[i],
                markeredgewidth=markeredgewidth, capsize=4, capthick=1, linestyle=linestyles[i])
ax.grid()

plt.xticks(np.arange(0, T_START+SIMULATION_INTERVAL, step=10))

ax.tick_params(axis='both', labelsize=tick_label_size)
ax.legend(['5Guard', 'OPT', 'IAR', 'DTR', 'RNR', 'NIS'], fontsize=legend_font_size)

if k != "reseff": ## Percentage data
    ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    ax.yaxis.get_major_formatter().set_scientific(True)
    ax.yaxis.get_major_formatter().set_powerlimits((-1, 1))
    ax.yaxis.offsetText.set_fontsize(20)  # Adjust font size

ax.set_xlabel(plot_titles[7][0], fontsize=xlabel_font_size)
ax.set_ylabel(plot_titles[7][1], fontsize=ylabel_font_size)
fig.tight_layout(pad=0.5)
plt.savefig(f"plots/result_7.svg", format="svg")

plt.show()
